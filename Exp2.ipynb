# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/simu_fixed_v2 \
  --name augan_l1_gan_experiment \
  --model augan \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --gpu_ids 0 \
  --norm batch \
  --no_flip \
  --continue_train \
  --epoch_count 30
# Out:
# [TRAIN] Dataset V29.0 (Standalone). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# [Network D] Total number of parameters : 11.061 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:50<00:00,  2.96batch/s, Edge=0.000, GAN=1.220, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 51 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0002000
#       G_GAN: 	 2.0498
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/simu_fixed_v2 \
  --name 02_augan_Pixel100_Gan1_VGG10_Tv0 \
  --checkpoints_dir /mnt/g/train_data \
  --model augan \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 10.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --gpu_ids 0 \
  --norm batch \
  --no_flip
# Out:
# [TRAIN] Dataset V29.0 (Standalone). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# ...

# %%
# ==================================================================================
# 1. [续训] 基准实验：L1=100, GAN=1.0
# 目的：接着之前的跑完，看看最终效果。
# ==================================================================================
# !python train.py --dataroot /home/liujia/g_linux/simu_fixed_v2 --name augan_l1_gan_experiment --checkpoints_dir /mnt/g/train_data/checkpoints --model augan --input_nc 3 --output_nc 1 --batch_size 2 --patch_size_d 128 --patch_size_h 64 --patch_size_w 64 --lambda_pixel 100.0 --lambda_gan 1.0 --lambda_perceptual 0.0 --lambda_tv 0.0 --lambda_edge 0.0 --gpu_ids 0 --norm batch --no_flip --continue_train --epoch_count 30

# ==================================================================================
# 2. [新实验] 纯 L1 回归：L1=100, GAN=0.0
# 目的：测试在没有 GAN 干扰的情况下，网络能否学对单纯的几何位置。
# ==================================================================================
# !python train.py --dataroot /home/liujia/g_linux/simu_fixed_v2 --name 02_augan_Pixel100_Gan0_Tv0 --checkpoints_dir /mnt/g/train_data/checkpoints --model augan --input_nc 3 --output_nc 1 --batch_size 2 --patch_size_d 128 --patch_size_h 64 --patch_size_w 64 --lambda_pixel 100.0 --lambda_gan 0.0 --lambda_perceptual 0.0 --lambda_tv 0.0 --lambda_edge 0.0 --gpu_ids 0 --norm batch --no_flip

# ==================================================================================
# 3. [新实验] 强判别器模式：L1=100, GAN=5.0
# 目的：加大 GAN 的权重，强迫生成器生成更锐利的边缘。
# ==================================================================================
# !python train.py --dataroot /home/liujia/g_linux/simu_fixed_v2 --name 03_augan_Pixel100_Gan5_Tv0 --checkpoints_dir /mnt/g/train_data/checkpoints --model augan --input_nc 3 --output_nc 1 --batch_size 2 --patch_size_d 128 --patch_size_h 64 --patch_size_w 64 --lambda_pixel 100.0 --lambda_gan 5.0 --lambda_perceptual 0.0 --lambda_tv 0.0 --lambda_edge 0.0 --gpu_ids 0 --norm batch --no_flip

# ==================================================================================
# 4. [新实验] 平滑模式：L1=100, GAN=1.0, TV=0.1
# 目的：加入 Total Variation Loss，测试是否能消除背景噪点。
# ==================================================================================
# !python train.py --dataroot /home/liujia/g_linux/simu_fixed_v2 --name 04_augan_Pixel100_Gan1_Tv0.1 --checkpoints_dir /mnt/g/train_data/checkpoints --model augan --input_nc 3 --output_nc 1 --batch_size 2 --patch_size_d 128 --patch_size_h 64 --patch_size_w 64 --lambda_pixel 100.0 --lambda_gan 1.0 --lambda_perceptual 0.0 --lambda_tv 0.1 --lambda_edge 0.0 --gpu_ids 0 --norm batch --no_flip
# Out:
# [TRAIN] Dataset V29.0 (Standalone). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/augan_l1_gan_experiment/latest_net_G.pth
# ...

# %%
# ==================================================================================
# 1. 测试实验 1：augan_l1_gan_experiment (基准续训)
# 模型读取位置：默认 ./checkpoints
# 结果保存位置：/mnt/g/train_data/test_results
# ==================================================================================
# !python test.py --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 --name augan_l1_gan_experiment --checkpoints_dir /mnt/g/train_data/checkpoints --results_dir /mnt/g/train_data/test_results --model augan --input_nc 3 --output_nc 1 --batch_size 1 --norm batch --no_flip --gpu_ids 0

# ==================================================================================
# 2. 测试实验 2：02_augan_Pixel100_Gan0_Tv0 (纯 L1)
# 模型读取位置：/mnt/g/train_data
# 结果保存位置：/mnt/g/train_data/test_results
# ==================================================================================
# !python test.py --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 --name 02_augan_Pixel100_Gan0_Tv0 --checkpoints_dir /mnt/g/train_data/checkpoints --results_dir /mnt/g/train_data/test_results --model augan --input_nc 3 --output_nc 1 --batch_size 1 --norm batch --no_flip --gpu_ids 0

# ==================================================================================
# 3. 测试实验 3：03_augan_Pixel100_Gan5_Tv0 (强 GAN)
# 模型读取位置：/mnt/g/train_data
# 结果保存位置：/mnt/g/train_data/test_results
# ==================================================================================
# !python test.py --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 --name 03_augan_Pixel100_Gan5_Tv0 --checkpoints_dir /mnt/g/train_data/checkpoints --results_dir /mnt/g/train_data/test_results --model augan --input_nc 3 --output_nc 1 --batch_size 1 --norm batch --no_flip --gpu_ids 0

# ==================================================================================
# 4. 测试实验 4：04_augan_Pixel100_Gan1_Tv0.1 (L1 + TV)
# 模型读取位置：/mnt/g/train_data
# 结果保存位置：/mnt/g/train_data/test_results
# ==================================================================================
# !python test.py --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 --name 04_augan_Pixel100_Gan1_Tv0.1 --checkpoints_dir /mnt/g/train_data/checkpoints --results_dir /mnt/g/train_data/test_results --model augan --input_nc 3 --output_nc 1 --batch_size 1 --norm batch --no_flip --gpu_ids 0
# Out:
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/augan_l1_gan_experiment/latest_net_G.pth
# ...
