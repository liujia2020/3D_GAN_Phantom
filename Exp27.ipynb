# %%
import sys
import torch
from options.train_options import TrainOptions
from data import create_dataset

# 伪造命令行参数
sys.argv = [
    'train.py',
    '--dataroot', '/home/liujia/g_linux/Phantom_Isotropic/', # 这里换成你 1024 深度的原始数据路径更好
    '--dir_lq', 'Recon_LQ_03',
    '--dir_sq', 'Recon_SQ_75',
    '--patch_size_h', '64',
    '--patch_size_w', '64'
]

opt = TrainOptions().parse()
dataset = create_dataset(opt)

print(f"数据集创建成功，总数: {len(dataset)}")

for i, data in enumerate(dataset):
    print(f"数据索引: {i}")
    print(f"LQ Tensor 形状 (应为 3, 64, 64): {data['lq'].shape}")
    print(f"SQ Tensor 形状 (应为 1, 64, 64): {data['sq'].shape}")
    print(f"样本名称: {data['case_name']}")
    break # 只测一条
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_31_25D_Slice_Final_Nearest_GAN1_FFL0.01_Epoch200 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 12 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.01 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode nearest
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 12                            	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_31_25D_Slice_Final_Nearest_GAN1_FFL0.01_Epoch200 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --upsample_mode nearest \
  --gpu_ids 0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3                             	[default: 1]
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_32_25D_Bilinear_L100_NoFFL \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 8 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 100.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 8                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_32_25D_Bilinear_L100_NoFFL \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3                             	[default: 1]
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_33_25D_VGG_Like_GAN2_FFL0.1 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 14 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 10.0 \
  --lambda_gan 2.0 \
  --lambda_ffl 0.1 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_33_25D_VGG_Like_GAN2_FFL0.1 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_34_25D_ASPP_Attention_L20 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 14 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 20.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.01 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_34_25D_ASPP_Attention_L20 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear


###################################################################################
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_35_25D_Batch16_Balance \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 14 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.01 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_35_25D_Batch16_Balance \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear


###################################################################################
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 14                            	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_36_25D_Base_L50 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 8 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 50.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_36_25D_Base_L50 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_37_25D_GAN3_L20 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 8 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 20.0 \
  --lambda_gan 3.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
 
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_37_25D_GAN3_L20 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_38_25D_BS16_ASPP_L30 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 16 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 30.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_38_25D_BS16_ASPP_L30 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_39_25D_Att_L10_GAN2 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 8 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 10.0 \
  --lambda_gan 2.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --use_attention \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_39_25D_Att_L10_GAN2 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_40_25D_All_In_BS16 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 16 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 30.0 \
  --lambda_gan 2.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 10.0 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_40_25D_All_In_BS16 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
####################################################################################
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 8                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_34_25D_ASPP_Att_L20 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_38_25D_BS16_ASPP_L30 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_39_25D_Att_L10_GAN2 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --use_attention \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear

# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_40_25D_All_In_BS16 \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3                             	[default: 1]
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_41_25D_Paper_Aligned_Charbonnier_VGG \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 12 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 1.0 \
  --lambda_gan 1.0 \
  --lambda_vgg 10.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 0.0 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 12                            	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_41_25D_Paper_Aligned_Charbonnier_VGG \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --gpu_ids 0 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3                             	[default: 1]
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_42_25D_Decoupled_Anisotropic \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --batch_size 12 \
  --patch_size_h 256 \
  --patch_size_w 256 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_vgg 10.0 \
  --lambda_ffl 0.0 \
  --lambda_ssim 0.0 \
  --use_sn \
  --use_dropout \
  --use_aspp \
  --use_attention \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode bilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 16                            	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...
