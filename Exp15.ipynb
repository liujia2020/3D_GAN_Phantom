# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name 55_Phantom_Finetune \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --continue_train \
  --epoch_count 1
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom/ 	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 55_Phantom_Finetune           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 55_Phantom_Finetune
# 📂 数据路径: /home/liujia/g_linux/Phantom/
# ================================================================================
#
# Traceback (most recent call last):
#   File "/home/liujia/3Channel/Clean_AUGAN/train.py", line 97, in <module>
#     dataset = create_dataset(opt)
#   File "/home/liujia/3Channel/Clean_AUGAN/data/__init__.py", line 11, in create_dataset
#     dataset = UltrasoundDataset(opt)
#   File "/home/liujia/3Channel/Clean_AUGAN/data/ultrasound_dataset.py", line 21, in __init__
#     self.lq_paths = sorted([os.path.join(self.dir_lq, f) for f in os.listdir(self.dir_lq) if f.endswith('.nii') or f.endswith('.nii.gz')])
# FileNotFoundError: [Errno 2] No such file or directory: '/home/liujia/g_linux/Phantom/Recon_LQ_03'

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name 55_Phantom_Finetune \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 5.0 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 200 \
  --n_epochs_decay 200 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --continue_train \
  --epoch_count 1 \
  --lr 0.00005
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom/ 	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 5.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 100.0
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 5e-05                         	[default: 0.0002]
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 200                           	[default: 100]
#            n_epochs_decay: 200                           	[default: 100]
#                n_layers_D: 3
#                      name: 55_Phantom_Finetune           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 55_Phantom_Finetune
# 📂 数据路径: /home/liujia/g_linux/Phantom/
# ================================================================================
#
# Traceback (most recent call last):
#   File "/home/liujia/3Channel/Clean_AUGAN/train.py", line 97, in <module>
#     dataset = create_dataset(opt)
#   File "/home/liujia/3Channel/Clean_AUGAN/data/__init__.py", line 11, in create_dataset
#     dataset = UltrasoundDataset(opt)
#   File "/home/liujia/3Channel/Clean_AUGAN/data/ultrasound_dataset.py", line 21, in __init__
#     self.lq_paths = sorted([os.path.join(self.dir_lq, f) for f in os.listdir(self.dir_lq) if f.endswith('.nii') or f.endswith('.nii.gz')])
# FileNotFoundError: [Errno 2] No such file or directory: '/home/liujia/g_linux/Phantom/Recon_LQ_03'

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 56_Phantom_Carotid_Real_Finetune \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 50.0 \
  --lambda_gan 5.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 200 \
  --n_epochs_decay 200 \
  --attn_temp 1.5 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --continue_train \
  --epoch_count 16 \
  --lr 0.00005
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 16                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 5.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 50.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 5e-05                         	[default: 0.0002]
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 200                           	[default: 100]
#            n_epochs_decay: 200                           	[default: 100]
#                n_layers_D: 3
#                      name: 56_Phantom_Carotid_Real_Finetune	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 56_Phantom_Carotid_Real_Finetune
# 📂 数据路径: /home/liujia/g_linux/Phantom_Carotid/
# ================================================================================
#
# Dataset V7 (Final). Found 201 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/56_Phantom_Carotid_Real_Finetune/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# Traceback (most recent call last):
#   File "/home/liujia/3Channel/Clean_AUGAN/train.py", line 101, in <module>
#     model.setup(opt)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/base_model.py", line 54, in setup
#     self.load_networks(load_suffix)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/base_model.py", line 120, in load_networks
#     state_dict = torch.load(load_path, map_location=str(self.device))
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/serialization.py", line 1360, in load
#     return _load(
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/serialization.py", line 1848, in _load
#     result = unpickler.load()
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/serialization.py", line 1812, in persistent_load
#     typed_storage = load_tensor(
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/serialization.py", line 1772, in load_tensor
#     zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)
# RuntimeError: PytorchStreamReader failed locating file data/2: file not found

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 57_Phantom_Carotid_Real_Finetune_Texture \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.00005 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --continue_train \
  --epoch_count 1 \
  --lambda_pixel 10.0 \
  --lambda_gan 5.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 58_Phantom_Carotid_Real_Finetune_Conservative \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.00005 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --continue_train \
  --epoch_count 1 \
  --lambda_pixel 100.0 \
  --lambda_gan 5.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 5.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 59_Phantom_Carotid_Real_Finetune_HighGAN \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.00005 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --continue_train \
  --epoch_count 1 \
  --lambda_pixel 50.0 \
  --lambda_gan 10.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 5.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 5e-05                         	[default: 0.0002]
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 57_Phantom_Carotid_Real_Finetune_Texture	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 57_Phantom_Carotid_Real_Finetune_Texture
# 📂 数据路径: /home/liujia/g_linux/Phantom_Carotid/
# ================================================================================
#
# Dataset V7 (Final). Found 201 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/57_Phantom_Carotid_Real_Finetune_Texture/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# loading the model from /mnt/g/train_data/checkpoints/57_Phantom_Carotid_Real_Finetune_Texture/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 1: 100%|███████████| 101/101 [01:08<00:00,  1.47it/s, L1=3.267, PSNR=13.7]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9912  |  Pixel: 2.5433  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0095  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0120  |  Fake: 0.0149
#   📊 [Metrics Avg]   |  PSNR: 16.68 dB  |  Time: 68.7s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 2: 100%|███████████| 101/101 [00:41<00:00,  2.44it/s, L1=2.687, PSNR=14.5]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0167  |  Pixel: 2.3121  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0100  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0055  |  Fake: 0.0079
#   📊 [Metrics Avg]   |  PSNR: 16.51 dB  |  Time: 41.4s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 3: 100%|███████████| 101/101 [00:41<00:00,  2.43it/s, L1=2.268, PSNR=17.2]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0030  |  Pixel: 2.1029  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0099  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0036  |  Fake: 0.0039
#   📊 [Metrics Avg]   |  PSNR: 17.52 dB  |  Time: 41.6s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 4: 100%|███████████| 101/101 [00:41<00:00,  2.44it/s, L1=1.933, PSNR=18.9]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0041  |  Pixel: 1.9732  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0096  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0054  |  Fake: 0.0093
#   📊 [Metrics Avg]   |  PSNR: 17.92 dB  |  Time: 41.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 5: 100%|███████████| 101/101 [00:41<00:00,  2.42it/s, L1=1.889, PSNR=17.7]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9945  |  Pixel: 2.0551  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0088  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0099  |  Fake: 0.0134
#   📊 [Metrics Avg]   |  PSNR: 17.79 dB  |  Time: 41.8s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 6: 100%|███████████| 101/101 [00:40<00:00,  2.50it/s, L1=1.926, PSNR=16.9]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9807  |  Pixel: 2.0947  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0079  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0111  |  Fake: 0.0136
#   📊 [Metrics Avg]   |  PSNR: 17.33 dB  |  Time: 40.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 7: 100%|███████████| 101/101 [00:40<00:00,  2.50it/s, L1=2.572, PSNR=16.6]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9808  |  Pixel: 2.0702  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0075  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0065  |  Fake: 0.0057
#   📊 [Metrics Avg]   |  PSNR: 17.48 dB  |  Time: 40.4s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 8: 100%|███████████| 101/101 [00:40<00:00,  2.50it/s, L1=1.918, PSNR=18.3]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9771  |  Pixel: 2.0832  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0078  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0089  |  Fake: 0.0106
#   📊 [Metrics Avg]   |  PSNR: 17.30 dB  |  Time: 40.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 9: 100%|███████████| 101/101 [00:40<00:00,  2.51it/s, L1=1.904, PSNR=18.6]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.
|  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0036  |  Fake: 0.0042
#   📊 [Metrics Avg]   |  PSNR: 17.19 dB  |  Time: 40.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 84: 100%|██████████| 101/101 [00:40<00:00,  2.50it/s, L1=2.140, PSNR=17.7]
#
# ==================== Epoch 84 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0008  |  Pixel: 2.1415  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0067  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0033  |  Fake: 0.0032
#   📊 [Metrics Avg]   |  PSNR: 17.38 dB  |  Time: 40.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 85: 100%|██████████| 101/101 [00:40<00:00,  2.50it/s, L1=2.201, PSNR=17.3]
#
# ==================== Epoch 85 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9999  |  Pixel: 2.2066  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0067  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0028  |  Fake: 0.0030
#   📊 [Metrics Avg]   |  PSNR: 17.20 dB  |  Time: 40.4s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 86: 100%|██████████| 101/101 [00:40<00:00,  2.47it/s, L1=2.383, PSNR=16.8]
#
# ==================== Epoch 86 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0024  |  Pixel: 2.1572  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0067  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0033  |  Fake: 0.0040
# ...
#
# ==================== Epoch 168 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.8357  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0106  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.87 dB  |  Time: 40.7s  |  LR: 0.000016
# ------------------------------------------------------------
#
# Epoch 169: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=7.520, PSNR=20.1]
#
# ==================== Epoch 169 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7993  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.90 dB  |  Time: 40.7s  |  LR: 0.000015
# ------------------------------------------------------------
#
# Epoch 170: 100%|█████████| 101/101 [00:40<00:00,  2.52it/s, L1=7.971, PSNR=19.1]
#
# ==================== Epoch 170 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7827  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0106  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.2s  |  LR: 0.000015
# ------------------------------------------------------------
#
# Epoch 171: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.484, PSNR=20.4]
#
# ==================== Epoch 171 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7753  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.93 dB  |  Time: 40.8s  |  LR: 0.000014
# ------------------------------------------------------------
#
# Epoch 172: 100%|████████| 101/101 [00:40<00:00,  2.49it/s, L1=11.121, PSNR=18.2]
#
# ==================== Epoch 172 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.8204  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.7s  |  LR: 0.000014
# ------------------------------------------------------------
#
# Epoch 173: 100%|█████████| 101/101 [00:40<00:00,  2.52it/s, L1=7.565, PSNR=20.8]
#
# ==================== Epoch 173 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.8064  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.99 dB  |  Time: 40.3s  |  LR: 0.000013
# ------------------------------------------------------------
#
# Epoch 174: 100%|█████████| 101/101 [00:45<00:00,  2.20it/s, L1=7.500, PSNR=19.5]
#
# ==================== Epoch 174 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7837  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.85 dB  |  Time: 46.1s  |  LR: 0.000013
# ------------------------------------------------------------
#
# Epoch 175: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=7.367, PSNR=20.6]
#
# ==================== Epoch 175 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7803  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.83 dB  |  Time: 40.6s  |  LR: 0.000012
# ------------------------------------------------------------
#
# Epoch 176: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.698, PSNR=20.2]
#
# ==================== Epoch 176 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9999  |  Pixel: 7.7139  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.04 dB  |  Time: 40.9s  |  LR: 0.000012
# ------------------------------------------------------------
#
# Epoch 177: 100%|█████████| 101/101 [00:40<00:00,  2.50it/s, L1=7.430, PSNR=20.6]
#
# ==================== Epoch 177 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0001  |  Pixel: 7.7378  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0106  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.93 dB  |  Time: 40.6s  |  LR: 0.000011
# ------------------------------------------------------------
#
# Epoch 178: 100%|█████████| 101/101 [00:40<00:00,  2.52it/s, L1=7.243, PSNR=20.3]
#
# ==================== Epoch 178 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7214  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.00 dB  |  Time: 40.2s  |  LR: 0.000011
# ------------------------------------------------------------
#
# Epoch 179: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.424, PSNR=19.9]
#
# ==================== Epoch 179 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7422  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.9s  |  LR: 0.000010
# ------------------------------------------------------------
#
# Epoch 180: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.810, PSNR=19.7]
#
# ==================== Epoch 180 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7818  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.86 dB  |  Time: 40.8s  |  LR: 0.000010
# ------------------------------------------------------------
#
# Epoch 181: 100%|█████████| 101/101 [00:40<00:00,  2.50it/s, L1=7.548, PSNR=20.7]
#
# ==================== Epoch 181 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7397  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0108  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.99 dB  |  Time: 40.5s  |  LR: 0.000009
# ------------------------------------------------------------
#
# Epoch 182: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=9.094, PSNR=18.3]
#
# ==================== Epoch 182 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7863  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.6s  |  LR: 0.000009
# ------------------------------------------------------------
#
# Epoch 183: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=7.798, PSNR=20.0]
#
# ==================== Epoch 183 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7872  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.7s  |  LR: 0.000008
# ------------------------------------------------------------
#
# Epoch 184: 100%|█████████| 101/101 [00:40<00:00,  2.51it/s, L1=7.312, PSNR=20.7]
#
# ==================== Epoch 184 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7380  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.00 dB  |  Time: 40.3s  |  LR: 0.000008
# ------------------------------------------------------------
#
# Epoch 185: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.458, PSNR=20.4]
#
# ==================== Epoch 185 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7682  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0108  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.01 dB  |  Time: 40.8s  |  LR: 0.000007
# ------------------------------------------------------------
#
# Epoch 186: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.418, PSNR=19.5]
#
# ==================== Epoch 186 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7003  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.99 dB  |  Time: 40.8s  |  LR: 0.000007
# ------------------------------------------------------------
#
# Epoch 187: 100%|█████████| 101/101 [00:40<00:00,  2.52it/s, L1=8.530, PSNR=19.6]
#
# ==================== Epoch 187 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7796  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0106  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.93 dB  |  Time: 40.1s  |  LR: 0.000006
# ------------------------------------------------------------
#
# Epoch 188: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.738, PSNR=20.3]
#
# ==================== Epoch 188 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7633  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.06 dB  |  Time: 40.8s  |  LR: 0.000006
# ------------------------------------------------------------
#
# Epoch 189: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=7.292, PSNR=20.6]
#
# ==================== Epoch 189 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7633  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0108  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.93 dB  |  Time: 40.8s  |  LR: 0.000005
# ------------------------------------------------------------
#
# Epoch 190: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=6.876, PSNR=21.4]
#
# ==================== Epoch 190 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7701  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 20.05 dB  |  Time: 40.9s  |  LR: 0.000005
# ------------------------------------------------------------
#
# Epoch 191: 100%|█████████| 101/101 [00:40<00:00,  2.47it/s, L1=7.125, PSNR=20.3]
#
# ==================== Epoch 191 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7683  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.93 dB  |  Time: 41.0s  |  LR: 0.000004
# ------------------------------------------------------------
#
# Epoch 192: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=7.420, PSNR=20.2]
#
# ==================== Epoch 192 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7742  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0108  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.97 dB  |  Time: 40.6s  |  LR: 0.000004
# ------------------------------------------------------------
#
# Epoch 193: 100%|█████████| 101/101 [00:40<00:00,  2.52it/s, L1=9.154, PSNR=19.3]
#
# ==================== Epoch 193 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7093  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.97 dB  |  Time: 40.2s  |  LR: 0.000003
# ------------------------------------------------------------
#
# Epoch 194: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=8.120, PSNR=19.1]
#
# ==================== Epoch 194 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7585  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.95 dB  |  Time: 40.6s  |  LR: 0.000003
# ------------------------------------------------------------
#
# Epoch 195: 100%|█████████| 101/101 [00:40<00:00,  2.50it/s, L1=8.244, PSNR=20.1]
#
# ==================== Epoch 195 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7408  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0106  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.97 dB  |  Time: 40.6s  |  LR: 0.000002
# ------------------------------------------------------------
#
# Epoch 196: 100%|█████████| 101/101 [00:39<00:00,  2.53it/s, L1=7.870, PSNR=20.1]
#
# ==================== Epoch 196 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.8217  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.92 dB  |  Time: 40.1s  |  LR: 0.000002
# ------------------------------------------------------------
#
# Epoch 197: 100%|█████████| 101/101 [00:40<00:00,  2.50it/s, L1=8.257, PSNR=19.3]
#
# ==================== Epoch 197 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7466  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.98 dB  |  Time: 40.5s  |  LR: 0.000001
# ------------------------------------------------------------
#
# Epoch 198: 100%|█████████| 101/101 [00:40<00:00,  2.49it/s, L1=7.564, PSNR=19.8]
#
# ==================== Epoch 198 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7777  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.97 dB  |  Time: 40.6s  |  LR: 0.000001
# ------------------------------------------------------------
#
# Epoch 199: 100%|█████████| 101/101 [00:45<00:00,  2.20it/s, L1=7.457, PSNR=20.4]
#
# ==================== Epoch 199 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7299  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.97 dB  |  Time: 45.9s  |  LR: 0.000000
# ------------------------------------------------------------
#
# Epoch 200: 100%|█████████| 101/101 [00:40<00:00,  2.48it/s, L1=8.227, PSNR=19.4]
#
# ==================== Epoch 200 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0000  |  Pixel: 7.7202  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0107  |  BG: 0.0000
#   ⚖️  [Discriminator] |  Real: 0.0000  |  Fake: 0.0000
#   📊 [Metrics Avg]   |  PSNR: 19.91 dB  |  Time: 40.7s  |  LR: 0.000000
# ------------------------------------------------------------
#
# 🏁 所有训练完成!

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel \
  --name 57_Phantom_Carotid_Real_Finetune_Texture \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --results_dir /mnt/g/train_data/results \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch latest \
  --num_test 200
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel \
  --name 58_Phantom_Carotid_Real_Finetune_Conservative \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --results_dir /mnt/g/train_data/results \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch latest \
  --num_test 200
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel \
  --name 59_Phantom_Carotid_Real_Finetune_HighGAN \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --results_dir /mnt/g/train_data/results \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --use_attention \
  --gpu_ids 0 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch latest \
  --num_test 200
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 57_Phantom_Carotid_Real_Finetune_Texture	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 200                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 57_Phantom_Carotid_Real_Finetune_Texture
# ================================================================================
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/57_Phantom_Carotid_Real_Finetune_Texture/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# -----------------------------------------------
# 📊 找到 2 个 LQ 测试文件
#
# Processing [1]: Phantom_100
#   ✅ PSNR: 25.18 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# Processing [2]: Simu_001
#   ✅ PSNR: 31.66 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/57_Phantom_Carotid_Real_Finetune_Texture
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 58_Phantom_Carotid_Real_Finetune_Conservative	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 200                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 58_Phantom_Carotid_Real_Finetune_Conservative
# ================================================================================
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/58_Phantom_Carotid_Real_Finetune_Conservative/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# -----------------------------------------------
# 📊 找到 2 个 LQ 测试文件
#
# Processing [1]: Phantom_100
#   ✅ PSNR: 32.22 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# Processing [2]: Simu_001
#   ✅ PSNR: 29.32 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/58_Phantom_Carotid_Real_Finetune_Conservative
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 59_Phantom_Carotid_Real_Finetune_HighGAN	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 200                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 59_Phantom_Carotid_Real_Finetune_HighGAN
# ================================================================================
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/59_Phantom_Carotid_Real_Finetune_HighGAN/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# -----------------------------------------------
# 📊 找到 2 个 LQ 测试文件
#
# Processing [1]: Phantom_100
#   ✅ PSNR: 32.29 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# Processing [2]: Simu_001
#   ✅ PSNR: 30.97 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/59_Phantom_Carotid_Real_Finetune_HighGAN
