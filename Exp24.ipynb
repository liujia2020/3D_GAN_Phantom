# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_14_IsoPhantom_ResU_L1w10_GANw1.0_DropT_SNT_FFL0.1_VGG0_Patch64_Batch4_Nearest \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --upsample_mode nearest
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_14_IsoPhantom_ResU_L1w10_GANw1.0_DropT_SNT_FFL0.1_VGG0_Patch64_Batch4_Nearest \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
# ...
