# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_data_1channel/ \
  --name 53_NoiseGate_30dB \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_data_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 52_CBAM_ResUnet_Final \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results

# %%
# !python gamma_fix.py \
  /mnt/g/train_data/results/52_CBAM_ResUnet_Final/Simu_001_52_CBAM_ResUnet_Final_Fake.nii \
  /mnt/g/train_data/results/52_CBAM_ResUnet_Final/Simu_001_Fixed_Gamma2.nii \
  2.0
