# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 68_Nearest_Conv_Fix \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --lambda_pixel 10.0 \
  --lambda_gan 5.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  --lambda_ffl 0.0 \
  --lambda_bg 0.0 \
  --epoch_count 1 \
  --save_epoch_freq 10 \
  --display_freq 200

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 68_Nearest_Conv_Fix \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --lambda_pixel 10.0 \
  --lambda_gan 5.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  --lambda_ffl 0.0 \
  --lambda_bg 0.0 \
  --epoch_count 1 \
  --save_epoch_freq 10 \
  --display_freq 200 \
  --continue_train \
  --epoch_count 16

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 68_Nearest_Conv_Fix \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --results_dir /mnt/g/train_data/results \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --gpu_ids 0 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch latest \
  --num_test 200

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 69_Nearest_Conv_Fix \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --lambda_pixel 10.0 \
  --lambda_gan 5.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  --lambda_ffl 0.0 \
  --lambda_bg 0.0 \
  --epoch_count 1 \
  --save_epoch_freq 10 \
  --display_freq 200
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 200                           	[default: 400]
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#               lambda_edge: 0.0
#                lambda_ffl: 0.0
#                lambda_gan: 5.0                           	[default: 1.0]
#         lambda_perceptual: 1.0                           	[default: 0.0]
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.5                           	[default: 0.0]
#                 lambda_tv: 0.1                           	[default: 0.0]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 69_Nearest_Conv_Fix           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: False
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 10                            	[default: 5]
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 69_Nearest_Conv_Fix
# 📂 数据路径: /home/liujia/g_linux/Phantom_Carotid/
# ================================================================================
#
# Dataset V7 (Final). Found 201 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# initialize network with normal
# initialize network with normal
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 188.419 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 1:   0%|                                          | 0/201 [00:02<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/liujia/3Channel/Clean_AUGAN/train.py", line 252, in <module>
#     model.optimize_parameters()
#   File "/home/liujia/3Channel/Clean_AUGAN/models/augan_model.py", line 227, in optimize_parameters
#     self.forward()
#   File "/home/liujia/3Channel/Clean_AUGAN/models/augan_model.py", line 131, in forward
#     self.fake_B = self.netG(self.input_A)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/parallel/data_parallel.py", line 191, in forward
#     return self.module(*inputs[0], **module_kwargs[0])
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 147, in forward
#     return self.model(input)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 207, in forward
#     if self.outermost: return self.model(x)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 161, in forward
#     x = self.refine_block(x)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 123, in forward
#     residual = self.cbam(residual)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 45, in forward
#     out = x * self.ca(x)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/3Channel/Clean_AUGAN/models/networks/generator.py", line 21, in forward
#     avg_out = self.fc(self.avg_pool(x))
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/container.py", line 250, in forward
#     input = module(input)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 725, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 720, in _conv_forward
#     return F.conv3d(
# RuntimeError: Given groups=1, expected weight to be at least 1 at dimension 0, but got weight of size [0, 1, 1, 1, 1] instead
