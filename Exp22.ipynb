# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 0.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode exp \
  --depth_weight_max 5.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name N_06_Phantom_Augan_ResU3D_B2_P128x64x64_L1w100_GANw1_FFLw0.1_BGw0_DepthExp5_SNTrue_AttnT2_NormB_NoFlip_Ep100d100 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode exp \
  --depth_weight_max 5.0 \
  --use_sn \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_06_Phantom_Augan_ResU3D_B2_P128x64x64_L1w100_GANw1_FFLw0.1_BGw0_DepthExp5_SNTrue_AttnT2_NormB_NoFlip_Ep100d100 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name N_06_Phantom_Augan_ResU3D_B2_P128x64x64_L1w100_GANw1_FFLw0.1_BGw0_DepthExp5_SNTrue_AttnT2_NormB_NoFlip_Ep100d100 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 
#   --results_dir /mnt/g/train_data/checkpoint_Phantom

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0
