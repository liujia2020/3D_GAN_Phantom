# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0 \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 100.0 \
  --lambda_gan 0.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode exp \
  --depth_weight_max 5.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: exp                           	[default: none]
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 0.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 100.0
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 05_Phantom_DepthWeightExp5_L1w100_GANw0_FFLw0.1_BGw0
# 📂 数据路径: /home/liujia/g_linux/Phantom_Carotid_Muscle/
# ================================================================================
#
# Dataset V7 (Final). Found 293 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# ⚠️ 未检测到 monitor_data，请确认你是否运行过 crop_monitor_patch.py！
# Epoch 1:   3%|▎           | 4/147 [00:20<12:20,  5.18s/it, L1=74.570, PSNR=15.1]
# Traceback (most recent call last):
#   File "/home/liujia/3D_GAN_Phantom/train.py", line 145, in <module>
#     fake_im_raw = tensor2im_custom(fake_tensor)
#   File "/home/liujia/3D_GAN_Phantom/train.py", line 26, in tensor2im_custom
#     image_numpy = image_tensor[0].cpu().float().numpy()
# KeyboardInterrupt
# ^C
