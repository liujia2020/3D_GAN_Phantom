# %%
! python train.py \
    --dataroot /root/autodl-tmp/train_data/AUGAN_DATA_Nii \
    --name run_Final_V7_CutSkip_BatchNorm \
    --model augan \
    --netG unet_3d \
    --batch_size 6 \
    --patch_size_d 256 \
    --patch_size_h 128 \
    --patch_size_w 128 \
    --pixel_loss L1 \
    --lambda_pixel 50.0 \
    --norm batch \
    --lr 0.0004 \
    --lr_d_ratio 0.1 \
    --spacing_z 0.0362 \
    --spacing_x 0.2 \
    --no_flip \
    --no_elastic \
    --gpu_ids 0 \
    --checkpoints_dir /root/autodl-tmp/checkpoints \
    --num_workers 8
# Out:
# Traceback (most recent call last):
#   File "/home/liujia/3Channel/train.py", line 70, in <module>
#     os.makedirs(log_dir, exist_ok=True)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/root/autodl-tmp'

# %%
# 请直接复制执行（确保修改了 --name）
! python train.py \
--dataroot /home/liujia/g_linux/train \
--name run_Attention_V11_Hybrid_test3 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 40.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 0.1 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3   \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4
# Out:
# [TRAIN] Dataset V24.0 (Shape Adaptive). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/train
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:50<00:00,  2.95batch/s, Edge=0.092, GAN=0.235, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 51 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
#       G_GAN: 	 0.7033
# ...

# %%
# 请直接复制执行（确保修改了 --name）
! python train.py \
--dataroot /home/liujia/g_linux/train \
--name run_Attention_V11_Hybrid_test4 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 40.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 0.1 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3   \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4
# Out:
# ✅ 成功加载全局 Max 统计表: 1500 条记录
# [TRAIN] Dataset V25.0 (Global Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/train
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:48<00:00,  3.07batch/s, Edge=0.027, GAN=0.243, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 49 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test \
  --name run_Attention_V11_Hybrid_test4 \
  --model augan \
  --netG unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --spacing_z 0.0362 \
  --spacing_x 0.2 \
  --epoch 200 \
  --gpu_ids 0 \
  --checkpoints_dir /mnt/g/train_data \
  --results_dir ./results
# Out:
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Attention_V11_Hybrid_test4/200_net_G.pth
# ...

# %%
# 请直接复制执行（确保修改了 --name）
! python train.py \
--dataroot /home/liujia/g_linux/train \
--name run_Attention_V11_Hybrid_test5_NoMuscle \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 40.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 0.1 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3   \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4
# Out:
# ✅ 成功加载全局 Max 统计表: 3010 条记录
# [TRAIN] Dataset V25.0 (Global Norm). Size: 502
# Dataset [UltrasoundDataset] created. Size: 502, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/train
#   - Dataset Size:  251 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 251/251 [01:27<00:00,  2.87batch/s, Edge=0.046, GAN=0.573, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 87 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0000400
# ...

# %%
# 请直接复制执行（确保修改了 --name）
! python train.py \
--dataroot /home/liujia/g_linux/train \
--name run_Attention_V11_Hybrid_simu2 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 40.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 0.1 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3   \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--

# %%
# 请直接复制执行（确保修改了 --name）
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Attention_V11_Hybrid_simu2 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 40.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 0.1 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3   \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--continue_train \
--epoch 170 \
--epoch_count 171
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Attention_V11_Hybrid_simu2/170_net_G.pth
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 \
  --name run_Attention_V11_Hybrid_simu2 \
  --model augan \
  --netG unet_3d \
  --input_nc 3 \
  --output_nc 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --spacing_z 0.0362 \
  --spacing_x 0.2 \
  --epoch 200 \
  --gpu_ids 0 \
  --checkpoints_dir /mnt/g/train_data \
  --results_dir /mnt/g/train_data/test_results
# Out:
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Attention_V11_Hybrid_simu2/200_net_G.pth
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_FixBlur_Pixel5_D1_Edge10 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 5.0 \
--lambda_edge 10.0 \
--lambda_perceptual 0.2 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:43<00:00,  3.45batch/s, Edge=0.022, GAN=0.100, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 43 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0004000
#       G_GAN: 	 5.5638
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Sharp_Pixel01_Edge20_VGG20 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 0.1 \
--lambda_edge 20.0 \
--lambda_perceptual 20.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:52<00:00,  2.83batch/s, Edge=0.128, GAN=0.448, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 53 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0004000
#       G_GAN: 	 6.7015
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Basic_Pixel1_GAN1_NoExtras \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 1.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:51<00:00,  2.90batch/s, Edge=0.000, GAN=0.268, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 52 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0004000
#       G_GAN: 	 6.3625
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Final_StandardL1_Pix100 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 100.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm instance \
--lr 0.0004 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 46.800 M
# [Network D] Total number of parameters : 11.060 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:52<00:00,  2.88batch/s, Edge=0.000, GAN=1.820, Perc
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 52 sec
#   Learning Rates: 	 G_lr = 0.0004000 | D_lr = 0.0004000
#       G_GAN: 	 4.4880
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_SimpleUNet_BatchNorm_Pix100 \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 100.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm batch \
--lr 0.0002 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# [Network D] Total number of parameters : 11.061 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:51<00:00,  2.91batch/s, Edge=0.000, GAN=0.497, Pixe
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 52 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0002000
#       G_GAN: 	 2.0341
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Final_GroupNorm_FixSmear \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 50.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm group \
--lr 0.0002 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# [Network D] Total number of parameters : 11.061 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [01:00<00:00,  2.46batch/s, Edge=0.000, GAN=0.265, Pixe
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 61 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0002000
#       G_GAN: 	 6.1429
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_GroupNorm_FastStart \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 50.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm group \
--lr 0.001 \
--init_type kaiming \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# [Network D] Total number of parameters : 11.061 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:56<00:00,  2.68batch/s, Edge=0.000, GAN=0.251, Pixe
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 56 sec
#   Learning Rates: 	 G_lr = 0.0010000 | D_lr = 0.0010000
#       G_GAN: 	 6.5910
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_GroupNorm_Pixel500_Slow \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 500.0 \
--lambda_edge 0.0 \
--lambda_perceptual 0.0 \
--norm group \
--lr 0.0002 \
--init_type normal \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--num_workers 4 \
--epoch 100 \
--epoch_count 1
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 44.394 M
# [Network D] Total number of parameters : 11.061 M
# -----------------------------------------------
#
# ...
#                          🚀 AUGAN TRAINING CONFIGURATION
# ...
#   - Device:        cuda:0
#   - Data Root:     /home/liujia/g_linux/simu_fixed_v2
#   - Dataset Size:  150 volumes
#   - Batch Size:    2
#   - Model:         G=unet_3d, D=pixel
# ...
#
# 📸 Saving initial sample (Step 0 check)...
#
# Start Epoch 1 / 200
# Epoch 1: 100%|█| 150/150 [00:54<00:00,  2.75batch/s, Edge=0.000, GAN=1.095, Pixe
# --------------------------------------------------------------------------------
# END OF EPOCH 1 / 200 	 Time Taken: 55 sec
#   Learning Rates: 	 G_lr = 0.0002000 | D_lr = 0.0002000
#       G_GAN: 	 6.1851
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_GroupNorm_Pixel500_Slow \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--pixel_loss L1 \
--lambda_pixel 50.0 \
--lambda_edge 10.0 \
--lambda_perceptual 0.0 \
--norm group \
--lr 0.0002 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--epoch 60 \
--checkpoints_dir /mnt/g/train_data/ \
--continue_train \
--epoch_count 60 \
--num_workers 4
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_GroupNorm_Pixel500_Slow/60_net_G.pth
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_GroupNorm_Pixel500_Slow \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--gan_mode lsgan \
--pixel_loss L1 \
--lambda_pixel 10.0 \
--lambda_edge 10.0 \
--lambda_perceptual 0.0 \
--norm group \
--lr 0.0002 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--continue_train \
--epoch_count 71 \
--epoch 70 \
--num_workers 4
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_GroupNorm_Pixel500_Slow/70_net_G.pth
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 \
  --name run_GroupNorm_Pixel500_Slow \
  --model augan \
  --netG unet_3d \
  --norm group \
  --input_nc 3 \
  --output_nc 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --spacing_z 0.0362 \
  --spacing_x 0.2 \
  --epoch 200 \
  --gpu_ids 0 \
  --checkpoints_dir /mnt/g/train_data \
  --results_dir /mnt/g/train_data/test_results
# Out:
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_GroupNorm_Pixel500_Slow/200_net_G.pth
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Final_VGG_Refine \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--gan_mode lsgan \
--pixel_loss L1 \
--lambda_pixel 10.0 \
--lambda_edge 10.0 \
--lambda_perceptual 0.1 \
--norm group \
--lr 0.0002 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--continue_train \
--epoch_count 201 \
--n_epochs 300 \
--num_workers 4
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Final_VGG_Refine/latest_net_G.pth
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_stand_fixed_v2 \
  --name run_Final_VGG_Refine \
  --model augan \
  --netG unet_3d \
  --norm group \
  --input_nc 3 \
  --output_nc 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --spacing_z 0.0362 \
  --spacing_x 0.2 \
  --epoch 400 \
  --gpu_ids 0 \
  --checkpoints_dir /mnt/g/train_data \
  --results_dir /mnt/g/train_data/test_results
# Out:
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Final_VGG_Refine/400_net_G.pth
# ...

# %%
! python train.py \
--dataroot /home/liujia/g_linux/simu_fixed_v2 \
--name run_Final_TV_Fix \
--model augan \
--netG unet_3d \
--batch_size 2 \
--patch_size_d 128 \
--patch_size_h 64 \
--patch_size_w 64 \
--gan_mode lsgan \
--pixel_loss L1 \
--lambda_pixel 100.0 \
--lambda_edge 10.0 \
--lambda_perceptual 0.1 \
--lambda_tv 2.0 \
--norm group \
--lr 0.0001 \
--lr_d_ratio 1.0 \
--spacing_z 0.0362 \
--spacing_x 0.2 \
--input_nc 3 \
--no_flip \
--no_elastic \
--gpu_ids 0 \
--checkpoints_dir /mnt/g/train_data/ \
--continue_train \
--epoch_count 401 \
--n_epochs 500 \
--n_epochs_decay 0 \
--num_workers 4
# Out:
# [TRAIN] Dataset V29.0 (Physics Fixed Norm). Size: 300
# Dataset [UltrasoundDataset] created. Size: 300, Batch Size: 2, Shuffle: True, Sampler: None, Workers: 4
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/run_Final_TV_Fix/latest_net_G.pth
# ...
