# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_15_Base_Nearest \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 0.0 \
  --lambda_ffl 0.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 15 \
  --n_epochs_decay 15 \
  --upsample_mode nearest
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_16_Base_Trilinear \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 0.0 \
  --lambda_ffl 0.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 15 \
  --n_epochs_decay 15 \
  --upsample_mode trilinear
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_17_Nearest_GAN_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_ffl 0.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 15 \
  --n_epochs_decay 15 \
  --upsample_mode nearest
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_18_Nearest_FFL_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 0.0 \
  --lambda_ffl 0.1 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 15 \
  --n_epochs_decay 15 \
  --upsample_mode nearest
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Isotropic/ \
  --name N_19_Trilinear_Attn_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 4 \
  --patch_size_d 64 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 0.0 \
  --lambda_ffl 0.0 \
  --use_attention \
  --attn_temp 2.0 \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --gpu_ids 0 \
  --n_epochs 15 \
  --n_epochs_decay 15 \
  --upsample_mode trilinear
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                lambda_gan: 0.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 15                            	[default: 100]
#            n_epochs_decay: 15                            	[default: 100]
#                n_layers_D: 3
#                      name: N_15_Base_Nearest             	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: nearest                       	[default: trilinear]
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: N_15_Base_Nearest
# 📂 数据路径: /home/liujia/g_linux/Phantom_Isotropic/
# ================================================================================
#
# Dataset V7 (Final). Found 293 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# 🔍 发现固定监控样本，正在加载...
# ✅ 固定监控样本加载完毕并已归一化！
# Epoch 1:   0%|                                           | 0/73 [00:00<?, ?it/s]/home/liujia/3D_GAN_Phantom-3D_GAN_Phantom_Isotropic/models/base_model.py:90: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 1: 100%|█████████████| 73/73 [00:49<00:00,  1.47it/s, L1=2.149, PSNR=19.3]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 2.2943
#   ⚖️  [Discriminator] |  real: 1.3754  |  fake: 1.7174
#   📊 [Metrics Avg]   |  Train PSNR: 17.39 dB  |  Time: 49.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 2: 100%|█████████████| 73/73 [00:22<00:00,  3.21it/s, L1=1.616, PSNR=19.9]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8863
#   ⚖️  [Discriminator] |  real: 0.3106  |  fake: 0.2996
#   📊 [Metrics Avg]   |  Train PSNR: 18.71 dB  |  Time: 22.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 3: 100%|█████████████| 73/73 [00:23<00:00,  3.13it/s, L1=1.590, PSNR=20.5]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8155
#   ⚖️  [Discriminator] |  real: 0.5841  |  fake: 0.5559
#   📊 [Metrics Avg]   |  Train PSNR: 18.74 dB  |  Time: 23.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 4: 100%|█████████████| 73/73 [00:23<00:00,  3.09it/s, L1=1.698, PSNR=18.3]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8021
#   ⚖️  [Discriminator] |  real: 0.2615  |  fake: 0.2652
#   📊 [Metrics Avg]   |  Train PSNR: 19.05 dB  |  Time: 23.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 5: 100%|█████████████| 73/73 [00:21<00:00,  3.47it/s, L1=1.734, PSNR=19.1]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7792
#   ⚖️  [Discriminator] |  real: 0.2774  |  fake: 0.2743
#   📊 [Metrics Avg]   |  Train PSNR: 18.99 dB  |  Time: 21.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 6: 100%|█████████████| 73/73 [00:21<00:00,  3.45it/s, L1=1.960, PSNR=15.7]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8072
#   ⚖️  [Discriminator] |  real: 0.3044  |  fake: 0.2990
#   📊 [Metrics Avg]   |  Train PSNR: 18.74 dB  |  Time: 21.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 7: 100%|█████████████| 73/73 [00:24<00:00,  3.03it/s, L1=1.893, PSNR=18.1]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7520
#   ⚖️  [Discriminator] |  real: 0.2608  |  fake: 0.2383
#   📊 [Metrics Avg]   |  Train PSNR: 18.91 dB  |  Time: 24.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 8: 100%|█████████████| 73/73 [00:23<00:00,  3.16it/s, L1=1.604, PSNR=19.8]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7473
#   ⚖️  [Discriminator] |  real: 0.1840  |  fake: 0.1699
#   📊 [Metrics Avg]   |  Train PSNR: 19.15 dB  |  Time: 23.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 9: 100%|█████████████| 73/73 [00:20<00:00,  3.49it/s, L1=2.126, PSNR=16.0]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7464
#   ⚖️  [Discriminator] |  real: 0.0996  |  fake: 0.0817
#   📊 [Metrics Avg]   |  Train PSNR: 19.16 dB  |  Time: 21.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 10: 100%|████████████| 73/73 [00:24<00:00,  3.01it/s, L1=1.648, PSNR=20.2]
#
# ==================== Epoch 10 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7360
#   ⚖️  [Discriminator] |  real: 0.0641  |  fake: 0.0651
#   📊 [Metrics Avg]   |  Train PSNR: 19.34 dB  |  Time: 24.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 11: 100%|████████████| 73/73 [00:23<00:00,  3.13it/s, L1=1.737, PSNR=18.3]
#
# ==================== Epoch 11 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7232
#   ⚖️  [Discriminator] |  real: 0.0353  |  fake: 0.0333
#   📊 [Metrics Avg]   |  Train PSNR: 19.18 dB  |  Time: 23.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 12: 100%|████████████| 73/73 [00:21<00:00,  3.42it/s, L1=1.641, PSNR=18.6]
#
# ==================== Epoch 12 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7225
#   ⚖️  [Discriminator] |  real: 0.0279  |  fake: 0.0241
#   📊 [Metrics Avg]   |  Train PSNR: 19.11 dB  |  Time: 21.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 13: 100%|████████████| 73/73 [00:23<00:00,  3.11it/s, L1=1.736, PSNR=20.3]
#
# ==================== Epoch 13 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7076
#   ⚖️  [Discriminator] |  real: 0.0173  |  fake: 0.0163
#   📊 [Metrics Avg]   |  Train PSNR: 19.23 dB  |  Time: 23.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 14: 100%|████████████| 73/73 [00:23<00:00,  3.05it/s, L1=1.702, PSNR=19.1]
#
# ==================== Epoch 14 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7164
#   ⚖️  [Discriminator] |  real: 0.0190  |  fake: 0.0163
#   📊 [Metrics Avg]   |  Train PSNR: 19.30 dB  |  Time: 24.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 15: 100%|████████████| 73/73 [00:21<00:00,  3.44it/s, L1=1.583, PSNR=20.1]
#
# ==================== Epoch 15 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7035
#   ⚖️  [Discriminator] |  real: 0.0167  |  fake: 0.0135
#   📊 [Metrics Avg]   |  Train PSNR: 19.29 dB  |  Time: 21.2s  |  LR: 0.000188
# ------------------------------------------------------------
#
# Epoch 16: 100%|████████████| 73/73 [00:21<00:00,  3.44it/s, L1=1.745, PSNR=17.7]
#
# ==================== Epoch 16 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7005
#   ⚖️  [Discriminator] |  real: 0.0115  |  fake: 0.0091
#   📊 [Metrics Avg]   |  Train PSNR: 19.16 dB  |  Time: 21.3s  |  LR: 0.000175
# ------------------------------------------------------------
#
# Epoch 17: 100%|████████████| 73/73 [00:23<00:00,  3.12it/s, L1=1.619, PSNR=18.9]
#
# ==================== Epoch 17 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6729
#   ⚖️  [Discriminator] |  real: 0.0105  |  fake: 0.0094
#   📊 [Metrics Avg]   |  Train PSNR: 19.39 dB  |  Time: 23.4s  |  LR: 0.000163
# ------------------------------------------------------------
#
# Epoch 18: 100%|████████████| 73/73 [00:28<00:00,  2.58it/s, L1=1.576, PSNR=19.9]
#
# ==================== Epoch 18 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7015
#   ⚖️  [Discriminator] |  real: 0.0086  |  fake: 0.0067
#   📊 [Metrics Avg]   |  Train PSNR: 19.33 dB  |  Time: 28.4s  |  LR: 0.000150
# ------------------------------------------------------------
#
# Epoch 19: 100%|████████████| 73/73 [00:23<00:00,  3.14it/s, L1=1.584, PSNR=20.3]
#
# ==================== Epoch 19 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6649
#   ⚖️  [Discriminator] |  real: 0.0074  |  fake: 0.0062
#   📊 [Metrics Avg]   |  Train PSNR: 19.51 dB  |  Time: 23.3s  |  LR: 0.000138
# ------------------------------------------------------------
#
# Epoch 20: 100%|████████████| 73/73 [00:21<00:00,  3.41it/s, L1=1.756, PSNR=19.3]
#
# ==================== Epoch 20 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6697
#   ⚖️  [Discriminator] |  real: 0.0061  |  fake: 0.0043
#   📊 [Metrics Avg]   |  Train PSNR: 19.53 dB  |  Time: 21.4s  |  LR: 0.000125
# ------------------------------------------------------------
#
# Epoch 21: 100%|████████████| 73/73 [00:24<00:00,  3.00it/s, L1=1.674, PSNR=19.4]
#
# ==================== Epoch 21 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6800
#   ⚖️  [Discriminator] |  real: 0.0056  |  fake: 0.0046
#   📊 [Metrics Avg]   |  Train PSNR: 19.47 dB  |  Time: 24.4s  |  LR: 0.000113
# ------------------------------------------------------------
#
# Epoch 22: 100%|████████████| 73/73 [00:21<00:00,  3.40it/s, L1=1.528, PSNR=20.7]
#
# ==================== Epoch 22 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6463
#   ⚖️  [Discriminator] |  real: 0.0050  |  fake: 0.0039
#   📊 [Metrics Avg]   |  Train PSNR: 19.59 dB  |  Time: 21.5s  |  LR: 0.000100
# ------------------------------------------------------------
#
# Epoch 23: 100%|████████████| 73/73 [00:23<00:00,  3.13it/s, L1=1.603, PSNR=20.0]
#
# ==================== Epoch 23 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6600
#   ⚖️  [Discriminator] |  real: 0.0043  |  fake: 0.0032
#   📊 [Metrics Avg]   |  Train PSNR: 19.22 dB  |  Time: 23.4s  |  LR: 0.000087
# ------------------------------------------------------------
#
# Epoch 24: 100%|████████████| 73/73 [00:23<00:00,  3.12it/s, L1=1.613, PSNR=20.7]
#
# ==================== Epoch 24 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6463
#   ⚖️  [Discriminator] |  real: 0.0036  |  fake: 0.0028
#   📊 [Metrics Avg]   |  Train PSNR: 19.65 dB  |  Time: 23.4s  |  LR: 0.000075
# ------------------------------------------------------------
#
# Epoch 25: 100%|████████████| 73/73 [00:21<00:00,  3.41it/s, L1=1.655, PSNR=20.1]
#
# ==================== Epoch 25 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6554
#   ⚖️  [Discriminator] |  real: 0.0036  |  fake: 0.0027
#   📊 [Metrics Avg]   |  Train PSNR: 19.49 dB  |  Time: 21.4s  |  LR: 0.000063
# ------------------------------------------------------------
#
# Epoch 26: 100%|████████████| 73/73 [00:21<00:00,  3.40it/s, L1=1.778, PSNR=17.4]
#
# ==================== Epoch 26 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6494
#   ⚖️  [Discriminator] |  real: 0.0036  |  fake: 0.0027
#   📊 [Metrics Avg]   |  Train PSNR: 19.50 dB  |  Time: 21.5s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 27: 100%|████████████| 73/73 [00:23<00:00,  3.11it/s, L1=1.743, PSNR=18.5]
#
# ==================== Epoch 27 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6457
#   ⚖️  [Discriminator] |  real: 0.0034  |  fake: 0.0025
#   📊 [Metrics Avg]   |  Train PSNR: 19.43 dB  |  Time: 23.5s  |  LR: 0.000038
# ------------------------------------------------------------
#
# Epoch 28: 100%|████████████| 73/73 [00:23<00:00,  3.12it/s, L1=1.629, PSNR=17.8]
#
# ==================== Epoch 28 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6327
#   ⚖️  [Discriminator] |  real: 0.0030  |  fake: 0.0023
#   📊 [Metrics Avg]   |  Train PSNR: 19.55 dB  |  Time: 23.4s  |  LR: 0.000025
# ------------------------------------------------------------
#
# Epoch 29: 100%|████████████| 73/73 [00:21<00:00,  3.40it/s, L1=1.668, PSNR=19.5]
#
# ==================== Epoch 29 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6273
#   ⚖️  [Discriminator] |  real: 0.0028  |  fake: 0.0019
#   📊 [Metrics Avg]   |  Train PSNR: 19.67 dB  |  Time: 21.5s  |  LR: 0.000013
# ------------------------------------------------------------
#
# Epoch 30: 100%|████████████| 73/73 [00:23<00:00,  3.15it/s, L1=1.672, PSNR=20.3]
#
# ==================== Epoch 30 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6370
#   ⚖️  [Discriminator] |  real: 0.0028  |  fake: 0.0019
#   📊 [Metrics Avg]   |  Train PSNR: 19.45 dB  |  Time: 23.2s  |  LR: 0.000000
# ------------------------------------------------------------
#
# 🏁 所有训练完成!
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                lambda_gan: 0.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 15                            	[default: 100]
#            n_epochs_decay: 15                            	[default: 100]
#                n_layers_D: 3
#                      name: N_16_Base_Trilinear           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: trilinear
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: N_16_Base_Trilinear
# 📂 数据路径: /home/liujia/g_linux/Phantom_Isotropic/
# ================================================================================
#
# Dataset V7 (Final). Found 293 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# 🔍 发现固定监控样本，正在加载...
# ✅ 固定监控样本加载完毕并已归一化！
# Epoch 1:   0%|                                           | 0/73 [00:00<?, ?it/s]/home/liujia/3D_GAN_Phantom-3D_GAN_Phantom_Isotropic/models/base_model.py:90: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 1: 100%|█████████████| 73/73 [00:54<00:00,  1.35it/s, L1=2.656, PSNR=16.9]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 2.2471
#   ⚖️  [Discriminator] |  real: 1.5767  |  fake: 1.7014
#   📊 [Metrics Avg]   |  Train PSNR: 17.39 dB  |  Time: 54.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 2: 100%|█████████████| 73/73 [00:26<00:00,  2.76it/s, L1=1.936, PSNR=18.9]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8825
#   ⚖️  [Discriminator] |  real: 0.4079  |  fake: 0.3976
#   📊 [Metrics Avg]   |  Train PSNR: 18.84 dB  |  Time: 26.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 3: 100%|█████████████| 73/73 [00:26<00:00,  2.74it/s, L1=1.845, PSNR=19.3]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8021
#   ⚖️  [Discriminator] |  real: 0.3051  |  fake: 0.2943
#   📊 [Metrics Avg]   |  Train PSNR: 19.19 dB  |  Time: 26.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 4: 100%|█████████████| 73/73 [00:26<00:00,  2.73it/s, L1=1.609, PSNR=20.3]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7777
#   ⚖️  [Discriminator] |  real: 0.2442  |  fake: 0.2308
#   📊 [Metrics Avg]   |  Train PSNR: 19.24 dB  |  Time: 26.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 5: 100%|█████████████| 73/73 [00:24<00:00,  2.98it/s, L1=1.833, PSNR=19.8]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7531
#   ⚖️  [Discriminator] |  real: 0.2544  |  fake: 0.2509
#   📊 [Metrics Avg]   |  Train PSNR: 19.43 dB  |  Time: 24.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 6: 100%|█████████████| 73/73 [00:26<00:00,  2.74it/s, L1=2.121, PSNR=19.4]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7526
#   ⚖️  [Discriminator] |  real: 0.4299  |  fake: 0.4416
#   📊 [Metrics Avg]   |  Train PSNR: 19.20 dB  |  Time: 26.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 7: 100%|█████████████| 73/73 [00:24<00:00,  2.96it/s, L1=1.860, PSNR=17.8]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7596
#   ⚖️  [Discriminator] |  real: 0.1742  |  fake: 0.1563
#   📊 [Metrics Avg]   |  Train PSNR: 18.96 dB  |  Time: 24.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 8: 100%|█████████████| 73/73 [00:26<00:00,  2.76it/s, L1=1.622, PSNR=19.4]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7200
#   ⚖️  [Discriminator] |  real: 0.1158  |  fake: 0.1070
#   📊 [Metrics Avg]   |  Train PSNR: 19.35 dB  |  Time: 26.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 9: 100%|█████████████| 73/73 [00:27<00:00,  2.70it/s, L1=1.769, PSNR=19.4]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7155
#   ⚖️  [Discriminator] |  real: 0.1175  |  fake: 0.1092
#   📊 [Metrics Avg]   |  Train PSNR: 19.32 dB  |  Time: 27.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 10: 100%|████████████| 73/73 [00:26<00:00,  2.70it/s, L1=1.551, PSNR=19.6]
#
# ==================== Epoch 10 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7288
#   ⚖️  [Discriminator] |  real: 0.0901  |  fake: 0.0862
#   📊 [Metrics Avg]   |  Train PSNR: 19.22 dB  |  Time: 27.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 11: 100%|████████████| 73/73 [00:25<00:00,  2.89it/s, L1=1.862, PSNR=18.4]
#
# ==================== Epoch 11 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6964
#   ⚖️  [Discriminator] |  real: 0.2529  |  fake: 0.2402
#   📊 [Metrics Avg]   |  Train PSNR: 19.30 dB  |  Time: 25.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 12: 100%|████████████| 73/73 [00:28<00:00,  2.58it/s, L1=1.624, PSNR=20.4]
#
# ==================== Epoch 12 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6918
#   ⚖️  [Discriminator] |  real: 0.1104  |  fake: 0.1040
#   📊 [Metrics Avg]   |  Train PSNR: 19.46 dB  |  Time: 28.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 13: 100%|████████████| 73/73 [00:26<00:00,  2.77it/s, L1=1.512, PSNR=20.9]
#
# ==================== Epoch 13 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6800
#   ⚖️  [Discriminator] |  real: 0.0345  |  fake: 0.0232
#   📊 [Metrics Avg]   |  Train PSNR: 19.39 dB  |  Time: 26.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 14: 100%|████████████| 73/73 [00:26<00:00,  2.71it/s, L1=1.607, PSNR=20.9]
#
# ==================== Epoch 14 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6995
#   ⚖️  [Discriminator] |  real: 0.0240  |  fake: 0.0219
#   📊 [Metrics Avg]   |  Train PSNR: 19.48 dB  |  Time: 27.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 15: 100%|████████████| 73/73 [00:25<00:00,  2.85it/s, L1=1.802, PSNR=19.2]
#
# ==================== Epoch 15 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6745
#   ⚖️  [Discriminator] |  real: 0.0185  |  fake: 0.0165
#   📊 [Metrics Avg]   |  Train PSNR: 19.57 dB  |  Time: 25.7s  |  LR: 0.000188
# ------------------------------------------------------------
#
# Epoch 16: 100%|████████████| 73/73 [00:24<00:00,  2.94it/s, L1=1.709, PSNR=20.4]
#
# ==================== Epoch 16 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6781
#   ⚖️  [Discriminator] |  real: 0.0159  |  fake: 0.0146
#   📊 [Metrics Avg]   |  Train PSNR: 19.35 dB  |  Time: 24.9s  |  LR: 0.000175
# ------------------------------------------------------------
#
# Epoch 17: 100%|████████████| 73/73 [00:27<00:00,  2.68it/s, L1=1.602, PSNR=19.7]
#
# ==================== Epoch 17 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6888
#   ⚖️  [Discriminator] |  real: 0.0127  |  fake: 0.0107
#   📊 [Metrics Avg]   |  Train PSNR: 19.41 dB  |  Time: 27.3s  |  LR: 0.000163
# ------------------------------------------------------------
#
# Epoch 18: 100%|████████████| 73/73 [00:30<00:00,  2.36it/s, L1=1.710, PSNR=19.3]
#
# ==================== Epoch 18 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6746
#   ⚖️  [Discriminator] |  real: 0.0104  |  fake: 0.0090
#   📊 [Metrics Avg]   |  Train PSNR: 19.48 dB  |  Time: 31.0s  |  LR: 0.000150
# ------------------------------------------------------------
#
# Epoch 19: 100%|████████████| 73/73 [00:26<00:00,  2.74it/s, L1=1.699, PSNR=20.1]
#
# ==================== Epoch 19 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6730
#   ⚖️  [Discriminator] |  real: 0.0090  |  fake: 0.0075
#   📊 [Metrics Avg]   |  Train PSNR: 19.42 dB  |  Time: 26.7s  |  LR: 0.000138
# ------------------------------------------------------------
#
# Epoch 20: 100%|████████████| 73/73 [00:26<00:00,  2.74it/s, L1=1.587, PSNR=18.7]
#
# ==================== Epoch 20 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6612
#   ⚖️  [Discriminator] |  real: 0.0082  |  fake: 0.0071
#   📊 [Metrics Avg]   |  Train PSNR: 19.37 dB  |  Time: 26.7s  |  LR: 0.000125
# ------------------------------------------------------------
#
# Epoch 21: 100%|████████████| 73/73 [00:26<00:00,  2.71it/s, L1=1.746, PSNR=20.4]
#
# ==================== Epoch 21 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6586
#   ⚖️  [Discriminator] |  real: 0.0067  |  fake: 0.0048
#   📊 [Metrics Avg]   |  Train PSNR: 19.60 dB  |  Time: 27.0s  |  LR: 0.000113
# ------------------------------------------------------------
#
# Epoch 22: 100%|████████████| 73/73 [00:26<00:00,  2.71it/s, L1=1.694, PSNR=19.8]
#
# ==================== Epoch 22 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6476
#   ⚖️  [Discriminator] |  real: 0.0064  |  fake: 0.0050
#   📊 [Metrics Avg]   |  Train PSNR: 19.64 dB  |  Time: 27.0s  |  LR: 0.000100
# ------------------------------------------------------------
#
# Epoch 23: 100%|████████████| 73/73 [00:25<00:00,  2.90it/s, L1=1.672, PSNR=19.6]
#
# ==================== Epoch 23 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6534
#   ⚖️  [Discriminator] |  real: 0.0051  |  fake: 0.0041
#   📊 [Metrics Avg]   |  Train PSNR: 19.39 dB  |  Time: 25.2s  |  LR: 0.000087
# ------------------------------------------------------------
#
# Epoch 24: 100%|████████████| 73/73 [00:26<00:00,  2.74it/s, L1=1.561, PSNR=20.1]
#
# ==================== Epoch 24 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6459
#   ⚖️  [Discriminator] |  real: 0.0050  |  fake: 0.0042
#   📊 [Metrics Avg]   |  Train PSNR: 19.75 dB  |  Time: 26.7s  |  LR: 0.000075
# ------------------------------------------------------------
#
# Epoch 25: 100%|████████████| 73/73 [00:26<00:00,  2.72it/s, L1=1.561, PSNR=19.4]
#
# ==================== Epoch 25 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6421
#   ⚖️  [Discriminator] |  real: 0.0048  |  fake: 0.0036
#   📊 [Metrics Avg]   |  Train PSNR: 19.55 dB  |  Time: 26.9s  |  LR: 0.000063
# ------------------------------------------------------------
#
# Epoch 26: 100%|████████████| 73/73 [00:26<00:00,  2.72it/s, L1=1.627, PSNR=20.4]
#
# ==================== Epoch 26 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6381
#   ⚖️  [Discriminator] |  real: 0.0044  |  fake: 0.0035
#   📊 [Metrics Avg]   |  Train PSNR: 19.58 dB  |  Time: 26.9s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 27: 100%|████████████| 73/73 [00:26<00:00,  2.72it/s, L1=1.639, PSNR=18.9]
#
# ==================== Epoch 27 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6372
#   ⚖️  [Discriminator] |  real: 0.0038  |  fake: 0.0028
#   📊 [Metrics Avg]   |  Train PSNR: 19.56 dB  |  Time: 26.9s  |  LR: 0.000038
# ------------------------------------------------------------
#
# Epoch 28: 100%|████████████| 73/73 [00:26<00:00,  2.72it/s, L1=1.669, PSNR=19.9]
#
# ==================== Epoch 28 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6431
#   ⚖️  [Discriminator] |  real: 0.0036  |  fake: 0.0026
#   📊 [Metrics Avg]   |  Train PSNR: 19.50 dB  |  Time: 26.8s  |  LR: 0.000025
# ------------------------------------------------------------
#
# Epoch 29: 100%|████████████| 73/73 [00:25<00:00,  2.86it/s, L1=1.545, PSNR=20.0]
#
# ==================== Epoch 29 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6425
#   ⚖️  [Discriminator] |  real: 0.0034  |  fake: 0.0026
#   📊 [Metrics Avg]   |  Train PSNR: 19.62 dB  |  Time: 25.5s  |  LR: 0.000013
# ------------------------------------------------------------
#
# Epoch 30: 100%|████████████| 73/73 [00:26<00:00,  2.71it/s, L1=1.619, PSNR=20.1]
#
# ==================== Epoch 30 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6196
#   ⚖️  [Discriminator] |  real: 0.0033  |  fake: 0.0023
#   📊 [Metrics Avg]   |  Train PSNR: 19.69 dB  |  Time: 26.9s  |  LR: 0.000000
# ------------------------------------------------------------
#
# 🏁 所有训练完成!
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                lambda_gan: 1.0
#         lambda_perceptual: 0.0
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 15                            	[default: 100]
#            n_epochs_decay: 15                            	[default: 100]
#                n_layers_D: 3
#                      name: N_17_Nearest_GAN_Only         	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: nearest                       	[default: trilinear]
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: N_17_Nearest_GAN_Only
# 📂 数据路径: /home/liujia/g_linux/Phantom_Isotropic/
# ================================================================================
#
# Dataset V7 (Final). Found 293 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# 🔍 发现固定监控样本，正在加载...
# ✅ 固定监控样本加载完毕并已归一化！
# Epoch 1:   0%|                                           | 0/73 [00:00<?, ?it/s]/home/liujia/3D_GAN_Phantom-3D_GAN_Phantom_Isotropic/models/base_model.py:90: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 1: 100%|█████████████| 73/73 [00:52<00:00,  1.40it/s, L1=2.194, PSNR=16.2]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.9206  |  L1: 3.0144
#   ⚖️  [Discriminator] |  real: 1.6262  |  fake: 1.4424
#   📊 [Metrics Avg]   |  Train PSNR: 14.95 dB  |  Time: 52.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 2: 100%|█████████████| 73/73 [00:21<00:00,  3.42it/s, L1=3.093, PSNR=19.0]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5751  |  L1: 2.1718
#   ⚖️  [Discriminator] |  real: 0.3464  |  fake: 0.3317
#   📊 [Metrics Avg]   |  Train PSNR: 17.78 dB  |  Time: 21.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 3: 100%|█████████████| 73/73 [00:23<00:00,  3.12it/s, L1=2.790, PSNR=19.1]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6150  |  L1: 2.0639
#   ⚖️  [Discriminator] |  real: 0.3048  |  fake: 0.3131
#   📊 [Metrics Avg]   |  Train PSNR: 18.31 dB  |  Time: 23.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 4: 100%|█████████████| 73/73 [00:23<00:00,  3.11it/s, L1=1.830, PSNR=19.1]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5923  |  L1: 1.9757
#   ⚖️  [Discriminator] |  real: 0.2869  |  fake: 0.2821
#   📊 [Metrics Avg]   |  Train PSNR: 18.44 dB  |  Time: 23.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 5: 100%|█████████████| 73/73 [00:21<00:00,  3.43it/s, L1=1.813, PSNR=19.2]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5458  |  L1: 1.9500
#   ⚖️  [Discriminator] |  real: 0.3063  |  fake: 0.2936
#   📊 [Metrics Avg]   |  Train PSNR: 18.38 dB  |  Time: 21.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 6: 100%|█████████████| 73/73 [00:21<00:00,  3.39it/s, L1=1.720, PSNR=19.5]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 1.0350  |  L1: 1.9447
#   ⚖️  [Discriminator] |  real: 0.8036  |  fake: 0.7061
#   📊 [Metrics Avg]   |  Train PSNR: 17.99 dB  |  Time: 21.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 7: 100%|█████████████| 73/73 [00:26<00:00,  2.81it/s, L1=2.543, PSNR=14.9]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.3957  |  L1: 1.8512
#   ⚖️  [Discriminator] |  real: 0.2723  |  fake: 0.2613
#   📊 [Metrics Avg]   |  Train PSNR: 18.80 dB  |  Time: 26.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 8: 100%|█████████████| 73/73 [00:26<00:00,  2.76it/s, L1=1.875, PSNR=18.7]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4614  |  L1: 1.8297
#   ⚖️  [Discriminator] |  real: 0.2300  |  fake: 0.2234
#   📊 [Metrics Avg]   |  Train PSNR: 18.76 dB  |  Time: 26.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 9: 100%|█████████████| 73/73 [00:26<00:00,  2.74it/s, L1=1.828, PSNR=18.0]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6472  |  L1: 1.8778
#   ⚖️  [Discriminator] |  real: 0.2438  |  fake: 0.2519
#   📊 [Metrics Avg]   |  Train PSNR: 18.62 dB  |  Time: 26.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 10: 100%|████████████| 73/73 [00:24<00:00,  2.97it/s, L1=1.953, PSNR=16.9]
#
# ==================== Epoch 10 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7079  |  L1: 1.9222
#   ⚖️  [Discriminator] |  real: 0.2148  |  fake: 0.2237
#   📊 [Metrics Avg]   |  Train PSNR: 18.53 dB  |  Time: 24.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 11: 100%|████████████| 73/73 [00:24<00:00,  2.95it/s, L1=2.234, PSNR=16.0]
#
# ==================== Epoch 11 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7685  |  L1: 1.9906
#   ⚖️  [Discriminator] |  real: 0.1700  |  fake: 0.1759
#   📊 [Metrics Avg]   |  Train PSNR: 17.92 dB  |  Time: 24.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 12: 100%|████████████| 73/73 [00:26<00:00,  2.80it/s, L1=2.077, PSNR=19.1]
#
# ==================== Epoch 12 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8344  |  L1: 2.1466
#   ⚖️  [Discriminator] |  real: 0.1783  |  fake: 0.1771
#   📊 [Metrics Avg]   |  Train PSNR: 17.73 dB  |  Time: 26.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 13: 100%|████████████| 73/73 [00:26<00:00,  2.71it/s, L1=2.199, PSNR=14.4]
#
# ==================== Epoch 13 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9349  |  L1: 2.0803
#   ⚖️  [Discriminator] |  real: 0.1547  |  fake: 0.1653
#   📊 [Metrics Avg]   |  Train PSNR: 17.60 dB  |  Time: 27.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 14: 100%|████████████| 73/73 [00:26<00:00,  2.76it/s, L1=2.115, PSNR=17.8]
#
# ==================== Epoch 14 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9461  |  L1: 2.1386
#   ⚖️  [Discriminator] |  real: 0.1115  |  fake: 0.1232
#   📊 [Metrics Avg]   |  Train PSNR: 17.53 dB  |  Time: 26.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 15: 100%|████████████| 73/73 [00:26<00:00,  2.77it/s, L1=2.073, PSNR=17.3]
#
# ==================== Epoch 15 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9691  |  L1: 2.1817
#   ⚖️  [Discriminator] |  real: 0.0618  |  fake: 0.0643
#   📊 [Metrics Avg]   |  Train PSNR: 17.10 dB  |  Time: 26.4s  |  LR: 0.000188
# ------------------------------------------------------------
#
# Epoch 16: 100%|████████████| 73/73 [00:26<00:00,  2.76it/s, L1=2.215, PSNR=17.7]
#
# ==================== Epoch 16 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9712  |  L1: 2.0933
#   ⚖️  [Discriminator] |  real: 0.0547  |  fake: 0.0536
#   📊 [Metrics Avg]   |  Train PSNR: 17.56 dB  |  Time: 26.5s  |  LR: 0.000175
# ------------------------------------------------------------
#
# Epoch 17: 100%|████████████| 73/73 [00:24<00:00,  2.92it/s, L1=2.091, PSNR=16.3]
#
# ==================== Epoch 17 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9972  |  L1: 2.1660
#   ⚖️  [Discriminator] |  real: 0.0437  |  fake: 0.0461
#   📊 [Metrics Avg]   |  Train PSNR: 17.41 dB  |  Time: 25.0s  |  LR: 0.000163
# ------------------------------------------------------------
#
# Epoch 18: 100%|████████████| 73/73 [00:31<00:00,  2.32it/s, L1=2.078, PSNR=18.4]
#
# ==================== Epoch 18 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9515  |  L1: 2.0754
#   ⚖️  [Discriminator] |  real: 0.0507  |  fake: 0.0513
#   📊 [Metrics Avg]   |  Train PSNR: 17.47 dB  |  Time: 31.5s  |  LR: 0.000150
# ------------------------------------------------------------
#
# Epoch 19: 100%|████████████| 73/73 [00:26<00:00,  2.76it/s, L1=2.197, PSNR=16.7]
#
# ==================== Epoch 19 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9836  |  L1: 2.0959
#   ⚖️  [Discriminator] |  real: 0.0378  |  fake: 0.0420
#   📊 [Metrics Avg]   |  Train PSNR: 17.45 dB  |  Time: 26.5s  |  LR: 0.000138
# ...
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                lambda_gan: 0.0                           	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 10.0                          	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 15                            	[default: 100]
#            n_epochs_decay: 15                            	[default: 100]
#                n_layers_D: 3
#                      name: N_19_Trilinear_Attn_Only      	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: trilinear
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: N_19_Trilinear_Attn_Only
# 📂 数据路径: /home/liujia/g_linux/Phantom_Isotropic/
# ================================================================================
#
# Dataset V7 (Final). Found 293 pairs.
# dataset [UltrasoundDataset] was created
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# 🔍 发现固定监控样本，正在加载...
# ✅ 固定监控样本加载完毕并已归一化！
# Epoch 1:   0%|                                           | 0/73 [00:00<?, ?it/s]/home/liujia/3D_GAN_Phantom-3D_GAN_Phantom_Isotropic/models/base_model.py:90: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   errors_ret[name] = float(getattr(self, 'loss_' + name))
# Epoch 1: 100%|█████████████| 73/73 [00:58<00:00,  1.24it/s, L1=2.332, PSNR=17.4]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 2.2660
#   ⚖️  [Discriminator] |  real: 1.9610  |  fake: 2.2443
#   📊 [Metrics Avg]   |  Train PSNR: 17.35 dB  |  Time: 58.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 2: 100%|█████████████| 73/73 [00:23<00:00,  3.05it/s, L1=1.750, PSNR=20.4]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.9153
#   ⚖️  [Discriminator] |  real: 0.3221  |  fake: 0.3111
#   📊 [Metrics Avg]   |  Train PSNR: 18.66 dB  |  Time: 24.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 3: 100%|█████████████| 73/73 [00:21<00:00,  3.33it/s, L1=1.772, PSNR=20.1]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.9138
#   ⚖️  [Discriminator] |  real: 0.2906  |  fake: 0.3026
#   📊 [Metrics Avg]   |  Train PSNR: 18.91 dB  |  Time: 22.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 4: 100%|█████████████| 73/73 [00:21<00:00,  3.33it/s, L1=1.951, PSNR=20.6]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.8603
#   ⚖️  [Discriminator] |  real: 0.2446  |  fake: 0.2302
#   📊 [Metrics Avg]   |  Train PSNR: 18.93 dB  |  Time: 21.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 5: 100%|█████████████| 73/73 [00:21<00:00,  3.34it/s, L1=1.936, PSNR=15.7]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7850
#   ⚖️  [Discriminator] |  real: 0.3267  |  fake: 0.3260
#   📊 [Metrics Avg]   |  Train PSNR: 19.10 dB  |  Time: 21.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 6: 100%|█████████████| 73/73 [00:21<00:00,  3.34it/s, L1=1.623, PSNR=20.2]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7656
#   ⚖️  [Discriminator] |  real: 0.2170  |  fake: 0.2130
#   📊 [Metrics Avg]   |  Train PSNR: 19.13 dB  |  Time: 21.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 7: 100%|█████████████| 73/73 [00:23<00:00,  3.04it/s, L1=1.617, PSNR=20.3]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7336
#   ⚖️  [Discriminator] |  real: 0.2306  |  fake: 0.2092
#   📊 [Metrics Avg]   |  Train PSNR: 19.14 dB  |  Time: 24.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 8: 100%|█████████████| 73/73 [00:24<00:00,  3.04it/s, L1=1.646, PSNR=18.9]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7694
#   ⚖️  [Discriminator] |  real: 0.1441  |  fake: 0.1380
#   📊 [Metrics Avg]   |  Train PSNR: 18.92 dB  |  Time: 24.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 9: 100%|█████████████| 73/73 [00:21<00:00,  3.34it/s, L1=1.675, PSNR=19.5]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7463
#   ⚖️  [Discriminator] |  real: 0.1623  |  fake: 0.1601
#   📊 [Metrics Avg]   |  Train PSNR: 19.13 dB  |  Time: 21.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 10: 100%|████████████| 73/73 [00:21<00:00,  3.35it/s, L1=1.933, PSNR=19.8]
#
# ==================== Epoch 10 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7256
#   ⚖️  [Discriminator] |  real: 0.0815  |  fake: 0.0711
#   📊 [Metrics Avg]   |  Train PSNR: 19.30 dB  |  Time: 24.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 11: 100%|████████████| 73/73 [00:23<00:00,  3.05it/s, L1=1.708, PSNR=20.0]
#
# ==================== Epoch 11 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7183
#   ⚖️  [Discriminator] |  real: 0.0566  |  fake: 0.0543
#   📊 [Metrics Avg]   |  Train PSNR: 19.32 dB  |  Time: 24.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 12: 100%|████████████| 73/73 [00:24<00:00,  3.02it/s, L1=1.705, PSNR=19.7]
#
# ==================== Epoch 12 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6932
#   ⚖️  [Discriminator] |  real: 0.0606  |  fake: 0.0519
#   📊 [Metrics Avg]   |  Train PSNR: 19.43 dB  |  Time: 24.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 13: 100%|████████████| 73/73 [00:21<00:00,  3.33it/s, L1=1.653, PSNR=19.6]
#
# ==================== Epoch 13 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7207
#   ⚖️  [Discriminator] |  real: 0.0478  |  fake: 0.0441
#   📊 [Metrics Avg]   |  Train PSNR: 19.34 dB  |  Time: 22.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 14: 100%|████████████| 73/73 [00:21<00:00,  3.35it/s, L1=1.851, PSNR=18.9]
#
# ==================== Epoch 14 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7028
#   ⚖️  [Discriminator] |  real: 0.0322  |  fake: 0.0267
#   📊 [Metrics Avg]   |  Train PSNR: 19.43 dB  |  Time: 21.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 15: 100%|████████████| 73/73 [00:23<00:00,  3.04it/s, L1=1.881, PSNR=20.0]
#
# ==================== Epoch 15 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7324
#   ⚖️  [Discriminator] |  real: 0.0239  |  fake: 0.0221
#   📊 [Metrics Avg]   |  Train PSNR: 19.26 dB  |  Time: 24.1s  |  LR: 0.000188
# ------------------------------------------------------------
#
# Epoch 16: 100%|████████████| 73/73 [00:24<00:00,  3.00it/s, L1=1.766, PSNR=19.6]
#
# ==================== Epoch 16 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7236
#   ⚖️  [Discriminator] |  real: 0.0153  |  fake: 0.0131
#   📊 [Metrics Avg]   |  Train PSNR: 19.18 dB  |  Time: 24.4s  |  LR: 0.000175
# ------------------------------------------------------------
#
# Epoch 17: 100%|████████████| 73/73 [00:21<00:00,  3.36it/s, L1=1.515, PSNR=20.1]
#
# ==================== Epoch 17 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6910
#   ⚖️  [Discriminator] |  real: 0.0156  |  fake: 0.0116
#   📊 [Metrics Avg]   |  Train PSNR: 19.24 dB  |  Time: 21.8s  |  LR: 0.000163
# ------------------------------------------------------------
#
# Epoch 18: 100%|████████████| 73/73 [00:28<00:00,  2.53it/s, L1=1.715, PSNR=19.9]
#
# ==================== Epoch 18 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6964
#   ⚖️  [Discriminator] |  real: 0.0132  |  fake: 0.0102
#   📊 [Metrics Avg]   |  Train PSNR: 19.56 dB  |  Time: 28.9s  |  LR: 0.000150
# ------------------------------------------------------------
#
# Epoch 19: 100%|████████████| 73/73 [00:24<00:00,  3.03it/s, L1=1.658, PSNR=18.6]
#
# ==================== Epoch 19 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7049
#   ⚖️  [Discriminator] |  real: 0.0126  |  fake: 0.0112
#   📊 [Metrics Avg]   |  Train PSNR: 19.22 dB  |  Time: 24.2s  |  LR: 0.000138
# ------------------------------------------------------------
#
# Epoch 20: 100%|████████████| 73/73 [00:24<00:00,  2.98it/s, L1=1.919, PSNR=18.3]
#
# ==================== Epoch 20 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6818
#   ⚖️  [Discriminator] |  real: 0.0106  |  fake: 0.0087
#   📊 [Metrics Avg]   |  Train PSNR: 19.50 dB  |  Time: 24.5s  |  LR: 0.000125
# ------------------------------------------------------------
#
# Epoch 21: 100%|████████████| 73/73 [00:24<00:00,  2.99it/s, L1=1.845, PSNR=18.8]
#
# ==================== Epoch 21 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.7007
#   ⚖️  [Discriminator] |  real: 0.0085  |  fake: 0.0070
#   📊 [Metrics Avg]   |  Train PSNR: 19.49 dB  |  Time: 24.5s  |  LR: 0.000113
# ------------------------------------------------------------
#
# Epoch 22: 100%|████████████| 73/73 [00:21<00:00,  3.40it/s, L1=1.702, PSNR=20.5]
#
# ==================== Epoch 22 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6671
#   ⚖️  [Discriminator] |  real: 0.0083  |  fake: 0.0068
#   📊 [Metrics Avg]   |  Train PSNR: 19.51 dB  |  Time: 21.5s  |  LR: 0.000100
# ------------------------------------------------------------
#
# Epoch 23: 100%|████████████| 73/73 [00:23<00:00,  3.05it/s, L1=1.577, PSNR=20.0]
#
# ==================== Epoch 23 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6775
#   ⚖️  [Discriminator] |  real: 0.0071  |  fake: 0.0061
#   📊 [Metrics Avg]   |  Train PSNR: 19.34 dB  |  Time: 24.0s  |  LR: 0.000087
# ------------------------------------------------------------
#
# Epoch 24: 100%|████████████| 73/73 [00:24<00:00,  2.95it/s, L1=1.700, PSNR=19.6]
#
# ==================== Epoch 24 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6814
#   ⚖️  [Discriminator] |  real: 0.0064  |  fake: 0.0049
#   📊 [Metrics Avg]   |  Train PSNR: 19.16 dB  |  Time: 24.8s  |  LR: 0.000075
# ------------------------------------------------------------
#
# Epoch 25: 100%|████████████| 73/73 [00:21<00:00,  3.41it/s, L1=1.638, PSNR=19.5]
#
# ==================== Epoch 25 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6668
#   ⚖️  [Discriminator] |  real: 0.0061  |  fake: 0.0047
#   📊 [Metrics Avg]   |  Train PSNR: 19.46 dB  |  Time: 21.5s  |  LR: 0.000063
# ------------------------------------------------------------
#
# Epoch 26: 100%|████████████| 73/73 [00:21<00:00,  3.38it/s, L1=1.534, PSNR=20.0]
#
# ==================== Epoch 26 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6519
#   ⚖️  [Discriminator] |  real: 0.0056  |  fake: 0.0044
#   📊 [Metrics Avg]   |  Train PSNR: 19.64 dB  |  Time: 21.6s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 27: 100%|████████████| 73/73 [00:23<00:00,  3.05it/s, L1=1.646, PSNR=20.5]
#
# ==================== Epoch 27 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6418
#   ⚖️  [Discriminator] |  real: 0.0050  |  fake: 0.0038
#   📊 [Metrics Avg]   |  Train PSNR: 19.62 dB  |  Time: 24.0s  |  LR: 0.000038
# ------------------------------------------------------------
#
# Epoch 28: 100%|████████████| 73/73 [00:24<00:00,  2.99it/s, L1=1.643, PSNR=18.9]
#
# ==================== Epoch 28 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6496
#   ⚖️  [Discriminator] |  real: 0.0050  |  fake: 0.0037
#   📊 [Metrics Avg]   |  Train PSNR: 19.61 dB  |  Time: 24.5s  |  LR: 0.000025
# ------------------------------------------------------------
#
# Epoch 29: 100%|████████████| 73/73 [00:21<00:00,  3.38it/s, L1=1.753, PSNR=18.4]
#
# ==================== Epoch 29 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6490
#   ⚖️  [Discriminator] |  real: 0.0047  |  fake: 0.0036
#   📊 [Metrics Avg]   |  Train PSNR: 19.69 dB  |  Time: 21.7s  |  LR: 0.000013
# ------------------------------------------------------------
#
# Epoch 30: 100%|████████████| 73/73 [00:23<00:00,  3.06it/s, L1=1.647, PSNR=20.6]
#
# ==================== Epoch 30 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.0000  |  L1: 1.6353
#   ⚖️  [Discriminator] |  real: 0.0042  |  fake: 0.0035
#   📊 [Metrics Avg]   |  Train PSNR: 19.66 dB  |  Time: 24.2s  |  LR: 0.000000
# ------------------------------------------------------------
#
# 🏁 所有训练完成!

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_15_Base_Nearest \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --upsample_mode nearest \
  --gpu_ids 0
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_16_Base_Trilinear \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --upsample_mode trilinear \
  --gpu_ids 0
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_17_Nearest_GAN_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --upsample_mode nearest \
  --gpu_ids 0
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_18_Nearest_FFL_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --upsample_mode nearest \
  --gpu_ids 0
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_Isotropic/ \
  --name N_19_Trilinear_Attn_Only \
  --checkpoints_dir /mnt/e/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_sn \
  --use_dropout \
  --use_attention \
  --attn_temp 2.0 \
  --upsample_mode trilinear \
  --gpu_ids 0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: N_15_Base_Nearest             	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: ./results/
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: nearest                       	[default: trilinear]
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): N_15_Base_Nearest
# ================================================================================
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# loading the model from /mnt/e/train_data/checkpoint_Phantom/N_15_Base_Nearest/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 31.26 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 31.90 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 32.45 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: ./results/N_15_Base_Nearest
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: N_16_Base_Trilinear           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: ./results/
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: trilinear
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): N_16_Base_Trilinear
# ================================================================================
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# loading the model from /mnt/e/train_data/checkpoint_Phantom/N_16_Base_Trilinear/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 31.60 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 32.13 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 32.39 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: ./results/N_16_Base_Trilinear
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: N_17_Nearest_GAN_Only         	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: ./results/
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: nearest                       	[default: trilinear]
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): N_17_Nearest_GAN_Only
# ================================================================================
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# loading the model from /mnt/e/train_data/checkpoint_Phantom/N_17_Nearest_GAN_Only/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 29.54 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 29.84 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 30.01 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: ./results/N_17_Nearest_GAN_Only
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: N_18_Nearest_FFL_Only         	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: ./results/
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: nearest                       	[default: trilinear]
#                  use_aspp: False
#             use_attention: False
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): N_18_Nearest_FFL_Only
# ================================================================================
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# loading the model from /mnt/e/train_data/checkpoint_Phantom/N_18_Nearest_FFL_Only/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.377 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 30.70 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 31.36 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 31.68 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: ./results/N_18_Nearest_FFL_Only
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/e/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom_Isotropic/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: N_19_Trilinear_Attn_Only      	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: ./results/
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             upsample_mode: trilinear
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#               use_dropout: True                          	[default: False]
#                    use_sn: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): N_19_Trilinear_Attn_Only
# ================================================================================
# /home/liujia/miniconda3/envs/augan_5090/lib/python3.10/site-packages/torch/nn/modules/conv.py:186: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# model [AuganModel] was created
# loading the model from /mnt/e/train_data/checkpoint_Phantom/N_19_Trilinear_Attn_Only/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 31.11 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 31.76 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 32.22 dB
#   Saving shape: (185, 128, 128) (Matches Orig: (185, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: ./results/N_19_Trilinear_Attn_Only
