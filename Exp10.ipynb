# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --lambda_ssim 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 5.0 
  
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.5 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 1.0 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 2.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.2 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 51                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 37_Base_Sharp1.5_FFL0.1_BG20  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 37_Base_Sharp1.5_FFL0.1_BG20
# 📂 数据路径: /home/liujia/g_linux/Simu_1channel/
# ================================================================================
#
# Dataset V7 (Final). Found 300 pairs.
# dataset [UltrasoundDataset] was created
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 51:   1%|▏          | 2/150 [00:23<25:42, 10.42s/it, L1=11.611, PSNR=23.5]^C

# %%
# !python train.py \
#   --dataroot /home/liujia/g_linux/Simu_1channel/ \
#   --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
#   --checkpoints_dir /mnt/g/train_data/checkpoints \
#   --dir_lq Recon_LQ_03 \
#   --dir_sq Recon_SQ_75 \
#   --model augan \
#   --netG res_unet_3d \
#   --input_nc 1 \
#   --output_nc 1 \
#   --batch_size 2 \
#   --patch_size_d 128 \
#   --patch_size_h 64 \
#   --patch_size_w 64 \
#   --lambda_pixel 200.0 \
#   --lambda_gan 10.0 \
#   --lambda_perceptual 0.0 \
#   --norm batch \
#   --no_flip \
#   --use_attention \
#   --use_dilation \
#   --gpu_ids 0 \
#   --n_epochs 100 \
#   --n_epochs_decay 100 \
#   --attn_temp 1.5 \
#   --lambda_ffl 1.0 \
#   --lambda_bg 50.0 \
#   --continue_train \
#   --epoch_count 56
      
  
# !python train.py \
#   --dataroot /home/liujia/g_linux/Simu_1channel/ \
#   --name 45_L1_Max_500_BG20 \
#   --checkpoints_dir /mnt/g/train_data/checkpoints \
#   --dir_lq Recon_LQ_03 \
#   --dir_sq Recon_SQ_75 \
#   --model augan \
#   --netG res_unet_3d \
#   --input_nc 1 \
#   --output_nc 1 \
#   --batch_size 2 \
#   --patch_size_d 128 \
#   --patch_size_h 64 \
#   --patch_size_w 64 \
#   --lambda_pixel 500.0 \
#   --lambda_gan 10.0 \
#   --lambda_perceptual 0.0 \
#   --norm batch \
#   --no_flip \
#   --use_attention \
#   --use_dilation \
#   --gpu_ids 0 \
#   --n_epochs 100 \
#   --n_epochs_decay 100 \
#   --attn_temp 1.5 \
#   --lambda_ffl 0.1 \
#   --lambda_bg 20.0

# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --continue_train \
  --epoch_count 136
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 51                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 46_NoDil_Sharp1.5_FFL0.1_BG20 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 46_NoDil_Sharp1.5_FFL0.1_BG20
# 📂 数据路径: /home/liujia/g_linux/Simu_1channel/
# ================================================================================
#
# Dataset V7 (Final). Found 300 pairs.
# dataset [UltrasoundDataset] was created
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 51: 100%|██████████| 150/150 [01:19<00:00,  1.88it/s, L1=3.637, PSNR=42.1]
#
# ==================== Epoch 51 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5491  |  Pixel: 6.6051  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0030  |  BG: 0.3209
#   ⚖️  [Discriminator] |  Real: 0.2578  |  Fake: 0.2138
#   📊 [Metrics Avg]   |  PSNR: 33.40 dB  |  Time: 79.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 52: 100%|██████████| 150/150 [00:59<00:00,  2.50it/s, L1=9.423, PSNR=25.0]
#
# ==================== Epoch 52 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4976  |  Pixel: 6.1774  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.2940
#   ⚖️  [Discriminator] |  Real: 0.2450  |  Fake: 0.2135
#   📊 [Metrics Avg]   |  PSNR: 32.98 dB  |  Time: 60.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 53: 100%|██████████| 150/150 [00:59<00:00,  2.51it/s, L1=8.557, PSNR=26.8]
#
# ==================== Epoch 53 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5131  |  Pixel: 6.3552  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3026
#   ⚖️  [Discriminator] |  Real: 0.2271  |  Fake: 0.2028
#   📊 [Metrics Avg]   |  PSNR: 32.21 dB  |  Time: 59.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 54: 100%|█████████| 150/150 [01:01<00:00,  2.45it/s, L1=10.426, PSNR=30.2]
#
# ==================== Epoch 54 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5318  |  Pixel: 6.7487  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0030  |  BG: 0.3209
#   ⚖️  [Discriminator] |  Real: 0.2330  |  Fake: 0.1947
#   📊 [Metrics Avg]   |  PSNR: 33.25 dB  |  Time: 61.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 55: 100%|██████████| 150/150 [01:03<00:00,  2.36it/s, L1=5.807, PSNR=35.6]
#
# ==================== Epoch 55 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5386  |  Pixel: 6.4051  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3101
#   ⚖️  [Discriminator] |  Real: 0.2338  |  Fake: 0.1959
#   📊 [Metrics Avg]   |  PSNR: 35.23 dB  |  Time: 63.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 56: 100%|██████████| 150/150 [00:58<00:00,  2.56it/s, L1=4.399, PSNR=27.6]
#
# ==================== Epoch 56 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5272  |  Pixel: 6.4030  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3089
#   ⚖️  [Discriminator] |  Real: 0.2201  |  Fake: 0.1849
#   📊 [Metrics Avg]   |  PSNR: 31.72 dB  |  Time: 58.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 57: 100%|██████████| 150/150 [00:58<00:00,  2.56it/s, L1=4.492, PSNR=26.0]
#
# ==================== Epoch 57 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5465  |  Pixel: 6.3329  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3040
#   ⚖️  [Discriminator] |  Real: 0.2287  |  Fake: 0.1869
#   📊 [Metrics Avg]   |  PSNR: 33.41 dB  |  Time: 58.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 58: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=12.382, PSNR=24.1]
#
# ==================== Epoch 58 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5500  |  Pixel: 6.4368  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0030  |  BG: 0.3103
#   ⚖️  [Discriminator] |  Real: 0.2087  |  Fake: 0.1764
#   📊 [Metrics Avg]   |  PSNR: 34.08 dB  |  Time: 58.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 59: 100%|██████████| 150/150 [01:03<00:00,  2.35it/s, L1=6.508, PSNR=25.4]
#
# ==================== Epoch 59 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5651  |  Pixel: 6.6295  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3186
#   ⚖️  [Discriminator] |  Real: 0.2185  |  Fake: 0.1760
#   📊 [Metrics Avg]   |  PSNR: 34.23 dB  |  Time: 63.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 60: 100%|██████████| 150/150 [01:02<00:00,  2.41it/s, L1=7.029, PSNR=22.7]
#
# ==================== Epoch 60 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5724  |  Pixel: 6.8637  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0030  |  BG: 0.3304
#   ⚖️  [Discriminator] |  Real: 0.2112  |  Fake: 0.1731
#   📊 [Metrics Avg]   |  PSNR: 32.94 dB  |  Time: 62.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 61: 100%|██████████| 150/150 [00:58<00:00,  2.56it/s, L1=5.319, PSNR=29.4]
#
# ==================== Epoch 61 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5581  |  Pixel: 6.5580  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3144
#   ⚖️  [Discriminator] |  Real: 0.2062  |  Fake: 0.1788
#   📊 [Metrics Avg]   |  PSNR: 32.31 dB  |  Time: 58.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 62: 100%|██████████| 150/150 [00:56<00:00,  2.65it/s, L1=6.291, PSNR=27.3]
#
# ==================== Epoch 62 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5757  |  Pixel: 6.6829  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0030  |  BG: 0.3188
#   ⚖️  [Discriminator] |  Real: 0.1960  |  Fake: 0.1701
#   📊 [Metrics Avg]   |  PSNR: 32.67 dB  |  Time: 56.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 63: 100%|█████████| 150/150 [00:56<00:00,  2.66it/s, L1=10.871, PSNR=26.1]
#
# ==================== Epoch 63 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5678  |  Pixel: 6.2516  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.2995
#   ⚖️  [Discriminator] |  Real: 0.2042  |  Fake: 0.1751
#   📊 [Metrics Avg]   |  PSNR: 32.97 dB  |  Time: 56.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 64: 100%|██████████| 150/150 [00:58<00:00,  2.55it/s, L1=7.518, PSNR=30.9]
#
# ==================== Epoch 64 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5916  |  Pixel: 6.4479  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3105
#   ⚖️  [Discriminator] |  Real: 0.2115  |  Fake: 0.1668
#   📊 [Metrics Avg]   |  PSNR: 33.46 dB  |  Time: 58.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 65: 100%|██████████| 150/150 [00:58<00:00,  2.55it/s, L1=7.209, PSNR=24.5]
#
# ==================== Epoch 65 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5851  |  Pixel: 6.5078  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3110
#   ⚖️  [Discriminator] |  Real: 0.2098  |  Fake: 0.1685
#   📊 [Metrics Avg]   |  PSNR: 35.65 dB  |  Time: 59.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 66: 100%|██████████| 150/150 [00:56<00:00,  2.63it/s, L1=5.536, PSNR=35.9]
#
# ==================== Epoch 66 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5776  |  Pixel: 6.3418  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3043
#   ⚖️  [Discriminator] |  Real: 0.1942  |  Fake: 0.1627
#   📊 [Metrics Avg]   |  PSNR: 33.09 dB  |  Time: 57.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 67: 100%|█████████| 150/150 [01:01<00:00,  2.46it/s, L1=15.103, PSNR=25.6]
#
# ==================== Epoch 67 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6071  |  Pixel: 6.4476  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3101
#   ⚖️  [Discriminator] |  Real: 0.1925  |  Fake: 0.1663
#   📊 [Metrics Avg]   |  PSNR: 34.72 dB  |  Time: 61.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 68: 100%|██████████| 150/150 [00:57<00:00,  2.61it/s, L1=0.053, PSNR=79.5]
#
# ==================== Epoch 68 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.5797  |  Pixel: 6.5940  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3156
#   ⚖️  [Discriminator] |  Real: 0.1964  |  Fake: 0.1562
#   📊 [Metrics Avg]   |  PSNR: 31.42 dB  |  Time: 57.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 69: 100%|██████████| 150/150 [00:56<00:00,  2.67it/s, L1=6.700, PSNR=30.1]
#
# ==================== Epoch 69 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6100  |  Pixel: 6.6096  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0029  |  BG: 0.3158
#   ⚖️  [Discriminator] |  Real: 0.2009  |  Fake: 0.1577
#   📊 [Metrics Avg]   |  PSNR: 33.28 dB  |  Time: 56.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 70: 100%|██████████| 150/150 [00:56<00:00,  2.67it/s, L1=8.128, PSNR=27.5]
#
# ==================== Epoch 70 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6013  |  Pixel: 6.2318  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3003
#   ⚖️  [Discriminator] |  Real: 0.1876  |  Fake: 0.1602
#   📊 [Metrics Avg]   |  PSNR: 33.49 dB  |  Time: 56.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 71: 100%|██████████| 150/150 [00:59<00:00,  2.53it/s, L1=5.415, PSNR=26.4]
#
# ==================== Epoch 71 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6146  |  Pixel: 6.3498  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3099
#   ⚖️  [Discriminator] |  Real: 0.1889  |  Fake: 0.1512
#   📊 [Metrics Avg]   |  PSNR: 32.21 dB  |  Time: 59.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 72: 100%|██████████| 150/150 [00:57<00:00,  2.61it/s, L1=1.679, PSNR=46.7]
#
# ==================== Epoch 72 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6104  |  Pixel: 6.3737  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3066
#   ⚖️  [Discriminator] |  Real: 0.1932  |  Fake: 0.1614
#   📊 [Metrics Avg]   |  PSNR: 32.94 dB  |  Time: 57.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 73: 100%|██████████| 150/150 [00:56<00:00,  2.64it/s, L1=9.286, PSNR=26.1]
#
# ==================== Epoch 73 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6321  |  Pixel: 6.5650  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3148
#   ⚖️  [Discriminator] |  Real: 0.1750  |  Fake: 0.1492
#   📊 [Metrics Avg]   |  PSNR: 33.10 dB  |  Time: 56.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 74: 100%|██████████| 150/150 [00:59<00:00,  2.54it/s, L1=1.156, PSNR=32.2]
#
# ==================== Epoch 74 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6518  |  Pixel: 6.3944  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3072
#   ⚖️  [Discriminator] |  Real: 0.1724  |  Fake: 0.1380
#   📊 [Metrics Avg]   |  PSNR: 34.26 dB  |  Time: 59.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 75: 100%|██████████| 150/150 [00:55<00:00,  2.69it/s, L1=8.314, PSNR=26.1]
#
# ==================== Epoch 75 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6473  |  Pixel: 6.5969  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3159
#   ⚖️  [Discriminator] |  Real: 0.1665  |  Fake: 0.1325
#   📊 [Metrics Avg]   |  PSNR: 33.10 dB  |  Time: 55.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 76: 100%|██████████| 150/150 [00:58<00:00,  2.57it/s, L1=9.281, PSNR=42.5]
#
# ==================== Epoch 76 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6807  |  Pixel: 6.7968  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3229
#   ⚖️  [Discriminator] |  Real: 0.1667  |  Fake: 0.1358
#   📊 [Metrics Avg]   |  PSNR: 31.46 dB  |  Time: 58.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 77: 100%|██████████| 150/150 [00:58<00:00,  2.58it/s, L1=5.725, PSNR=31.9]
#
# ==================== Epoch 77 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6467  |  Pixel: 6.4056  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3067
#   ⚖️  [Discriminator] |  Real: 0.1695  |  Fake: 0.1359
#   📊 [Metrics Avg]   |  PSNR: 33.29 dB  |  Time: 58.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 78: 100%|██████████| 150/150 [00:54<00:00,  2.73it/s, L1=2.177, PSNR=26.5]
#
# ==================== Epoch 78 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6705  |  Pixel: 6.4141  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3082
#   ⚖️  [Discriminator] |  Real: 0.1634  |  Fake: 0.1359
#   📊 [Metrics Avg]   |  PSNR: 33.82 dB  |  Time: 55.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 79: 100%|█████████| 150/150 [00:55<00:00,  2.72it/s, L1=12.132, PSNR=25.7]
#
# ==================== Epoch 79 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6617  |  Pixel: 6.5371  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0028  |  BG: 0.3144
#   ⚖️  [Discriminator] |  Real: 0.1662  |  Fake: 0.1343
#   📊 [Metrics Avg]   |  PSNR: 33.97 dB  |  Time: 55.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 80: 100%|██████████| 150/150 [00:56<00:00,  2.67it/s, L1=9.555, PSNR=29.8]
#
# ==================== Epoch 80 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6651  |  Pixel: 6.5208  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3111
#   ⚖️  [Discriminator] |  Real: 0.1680  |  Fake: 0.1313
#   📊 [Metrics Avg]   |  PSNR: 32.16 dB  |  Time: 56.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 81: 100%|██████████| 150/150 [00:56<00:00,  2.66it/s, L1=7.441, PSNR=26.4]
#
# ==================== Epoch 81 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6944  |  Pixel: 6.3818  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3089
#   ⚖️  [Discriminator] |  Real: 0.1458  |  Fake: 0.1271
#   📊 [Metrics Avg]   |  PSNR: 34.50 dB  |  Time: 56.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 82: 100%|██████████| 150/150 [00:55<00:00,  2.70it/s, L1=6.504, PSNR=27.1]
#
# ==================== Epoch 82 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6815  |  Pixel: 6.2151  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3003
#   ⚖️  [Discriminator] |  Real: 0.1556  |  Fake: 0.1293
#   📊 [Metrics Avg]   |  PSNR: 33.60 dB  |  Time: 55.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 83: 100%|██████████| 150/150 [00:57<00:00,  2.61it/s, L1=9.099, PSNR=29.4]
#
# ==================== Epoch 83 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7102  |  Pixel: 6.4157  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3056
#   ⚖️  [Discriminator] |  Real: 0.1488  |  Fake: 0.1183
#   📊 [Metrics Avg]   |  PSNR: 34.14 dB  |  Time: 57.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 84: 100%|██████████| 150/150 [01:01<00:00,  2.46it/s, L1=6.128, PSNR=30.2]
#
# ==================== Epoch 84 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7180  |  Pixel: 6.4864  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3060
#   ⚖️  [Discriminator] |  Real: 0.1467  |  Fake: 0.1188
#   📊 [Metrics Avg]   |  PSNR: 32.22 dB  |  Time: 61.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 85: 100%|██████████| 150/150 [00:55<00:00,  2.71it/s, L1=5.588, PSNR=28.1]
#
# ==================== Epoch 85 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7410  |  Pixel: 6.4060  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3038
#   ⚖️  [Discriminator] |  Real: 0.1336  |  Fake: 0.1143
#   📊 [Metrics Avg]   |  PSNR: 34.05 dB  |  Time: 55.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 86: 100%|██████████| 150/150 [00:58<00:00,  2.56it/s, L1=6.245, PSNR=40.4]
#
# ==================== Epoch 86 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7262  |  Pixel: 6.4133  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3058
#   ⚖️  [Discriminator] |  Real: 0.1387  |  Fake: 0.1200
#   📊 [Metrics Avg]   |  PSNR: 32.20 dB  |  Time: 58.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 87: 100%|██████████| 150/150 [00:57<00:00,  2.63it/s, L1=1.751, PSNR=37.4]
#
# ==================== Epoch 87 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7493  |  Pixel: 6.4092  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3072
#   ⚖️  [Discriminator] |  Real: 0.1216  |  Fake: 0.0948
#   📊 [Metrics Avg]   |  PSNR: 32.76 dB  |  Time: 57.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 88: 100%|█████████| 150/150 [00:56<00:00,  2.64it/s, L1=11.360, PSNR=26.8]
#
# ==================== Epoch 88 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7390  |  Pixel: 6.4645  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3058
#   ⚖️  [Discriminator] |  Real: 0.1418  |  Fake: 0.1199
#   📊 [Metrics Avg]   |  PSNR: 35.32 dB  |  Time: 56.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 89: 100%|██████████| 150/150 [00:56<00:00,  2.67it/s, L1=7.839, PSNR=26.5]
#
# ==================== Epoch 89 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7361  |  Pixel: 6.3948  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3045
#   ⚖️  [Discriminator] |  Real: 0.1342  |  Fake: 0.1131
#   📊 [Metrics Avg]   |  PSNR: 35.37 dB  |  Time: 56.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 90: 100%|██████████| 150/150 [00:55<00:00,  2.68it/s, L1=4.979, PSNR=30.2]
#
# ==================== Epoch 90 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7206  |  Pixel: 6.2780  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2989
#   ⚖️  [Discriminator] |  Real: 0.1379  |  Fake: 0.1159
#   📊 [Metrics Avg]   |  PSNR: 34.91 dB  |  Time: 56.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 91: 100%|█████████| 150/150 [00:57<00:00,  2.62it/s, L1=10.070, PSNR=25.8]
#
# ==================== Epoch 91 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7968  |  Pixel: 6.7271  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0027  |  BG: 0.3229
#   ⚖️  [Discriminator] |  Real: 0.1107  |  Fake: 0.0885
#   📊 [Metrics Avg]   |  PSNR: 34.75 dB  |  Time: 57.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 92: 100%|██████████| 150/150 [00:58<00:00,  2.57it/s, L1=4.296, PSNR=34.4]
#
# ==================== Epoch 92 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7312  |  Pixel: 6.1139  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2914
#   ⚖️  [Discriminator] |  Real: 0.1376  |  Fake: 0.1118
#   📊 [Metrics Avg]   |  PSNR: 35.13 dB  |  Time: 58.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 93: 100%|██████████| 150/150 [00:58<00:00,  2.55it/s, L1=4.594, PSNR=27.7]
#
# ==================== Epoch 93 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7916  |  Pixel: 6.3291  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3062
#   ⚖️  [Discriminator] |  Real: 0.1010  |  Fake: 0.0852
#   📊 [Metrics Avg]   |  PSNR: 32.92 dB  |  Time: 58.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 94: 100%|██████████| 150/150 [00:58<00:00,  2.56it/s, L1=6.877, PSNR=46.7]
#
# ==================== Epoch 94 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8132  |  Pixel: 6.3259  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3050
#   ⚖️  [Discriminator] |  Real: 0.1050  |  Fake: 0.0869
#   📊 [Metrics Avg]   |  PSNR: 32.24 dB  |  Time: 58.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 95: 100%|██████████| 150/150 [00:58<00:00,  2.55it/s, L1=7.605, PSNR=50.5]
#
# ==================== Epoch 95 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7666  |  Pixel: 6.4583  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3068
#   ⚖️  [Discriminator] |  Real: 0.1306  |  Fake: 0.1191
#   📊 [Metrics Avg]   |  PSNR: 34.82 dB  |  Time: 58.9s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 96: 100%|██████████| 150/150 [00:59<00:00,  2.53it/s, L1=6.219, PSNR=29.1]
#
# ==================== Epoch 96 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7905  |  Pixel: 6.4268  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3055
#   ⚖️  [Discriminator] |  Real: 0.1139  |  Fake: 0.0924
#   📊 [Metrics Avg]   |  PSNR: 35.36 dB  |  Time: 59.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 97: 100%|██████████| 150/150 [00:59<00:00,  2.54it/s, L1=8.892, PSNR=30.3]
#
# ==================== Epoch 97 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8195  |  Pixel: 6.6154  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3121
#   ⚖️  [Discriminator] |  Real: 0.0991  |  Fake: 0.0898
#   📊 [Metrics Avg]   |  PSNR: 32.55 dB  |  Time: 59.2s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 98: 100%|██████████| 150/150 [00:59<00:00,  2.54it/s, L1=5.053, PSNR=24.0]
#
# ==================== Epoch 98 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7806  |  Pixel: 6.3114  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3026
#   ⚖️  [Discriminator] |  Real: 0.1166  |  Fake: 0.0935
#   📊 [Metrics Avg]   |  PSNR: 33.25 dB  |  Time: 59.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 99: 100%|██████████| 150/150 [00:59<00:00,  2.52it/s, L1=6.612, PSNR=22.6]
#
# ==================== Epoch 99 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7814  |  Pixel: 6.2771  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2992
#   ⚖️  [Discriminator] |  Real: 0.1189  |  Fake: 0.0936
#   📊 [Metrics Avg]   |  PSNR: 33.83 dB  |  Time: 59.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 100: 100%|█████████| 150/150 [01:09<00:00,  2.16it/s, L1=7.298, PSNR=31.1]
#
# ==================== Epoch 100 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7511  |  Pixel: 6.3202  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3014
#   ⚖️  [Discriminator] |  Real: 0.1318  |  Fake: 0.1020
#   📊 [Metrics Avg]   |  PSNR: 35.11 dB  |  Time: 69.7s  |  LR: 0.000198
# ------------------------------------------------------------
#
# Epoch 101: 100%|█████████| 150/150 [01:00<00:00,  2.49it/s, L1=6.242, PSNR=36.8]
#
# ==================== Epoch 101 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8321  |  Pixel: 6.3491  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3033
#   ⚖️  [Discriminator] |  Real: 0.0926  |  Fake: 0.0776
#   📊 [Metrics Avg]   |  PSNR: 33.54 dB  |  Time: 60.2s  |  LR: 0.000196
# ------------------------------------------------------------
#
# Epoch 102: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=5.562, PSNR=40.2]
#
# ==================== Epoch 102 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.7905  |  Pixel: 6.3946  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3085
#   ⚖️  [Discriminator] |  Real: 0.1088  |  Fake: 0.1058
#   📊 [Metrics Avg]   |  PSNR: 33.97 dB  |  Time: 58.5s  |  LR: 0.000194
# ------------------------------------------------------------
#
# Epoch 103: 100%|█████████| 150/150 [01:00<00:00,  2.48it/s, L1=3.125, PSNR=32.1]
#
# ==================== Epoch 103 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8235  |  Pixel: 6.1710  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2984
#   ⚖️  [Discriminator] |  Real: 0.0997  |  Fake: 0.0816
#   📊 [Metrics Avg]   |  PSNR: 35.02 dB  |  Time: 60.6s  |  LR: 0.000192
# ------------------------------------------------------------
#
# Epoch 104: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=2.196, PSNR=31.7]
#
# ==================== Epoch 104 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8240  |  Pixel: 6.4070  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3067
#   ⚖️  [Discriminator] |  Real: 0.0984  |  Fake: 0.0822
#   📊 [Metrics Avg]   |  PSNR: 33.50 dB  |  Time: 58.5s  |  LR: 0.000190
# ------------------------------------------------------------
#
# Epoch 105: 100%|█████████| 150/150 [00:58<00:00,  2.58it/s, L1=3.815, PSNR=29.3]
#
# ==================== Epoch 105 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8202  |  Pixel: 6.1135  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2929
#   ⚖️  [Discriminator] |  Real: 0.0934  |  Fake: 0.0729
#   📊 [Metrics Avg]   |  PSNR: 32.92 dB  |  Time: 58.3s  |  LR: 0.000188
# ------------------------------------------------------------
#
# Epoch 106: 100%|█████████| 150/150 [00:58<00:00,  2.55it/s, L1=2.651, PSNR=35.5]
#
# ==================== Epoch 106 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8500  |  Pixel: 6.0704  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2894
#   ⚖️  [Discriminator] |  Real: 0.0768  |  Fake: 0.0677
#   📊 [Metrics Avg]   |  PSNR: 33.54 dB  |  Time: 58.9s  |  LR: 0.000186
# ------------------------------------------------------------
#
# Epoch 107: 100%|█████████| 150/150 [00:58<00:00,  2.55it/s, L1=9.015, PSNR=26.7]
#
# ==================== Epoch 107 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8419  |  Pixel: 6.3108  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2981
#   ⚖️  [Discriminator] |  Real: 0.0889  |  Fake: 0.0714
#   📊 [Metrics Avg]   |  PSNR: 33.93 dB  |  Time: 59.0s  |  LR: 0.000184
# ------------------------------------------------------------
#
# Epoch 108: 100%|█████████| 150/150 [00:59<00:00,  2.52it/s, L1=7.822, PSNR=27.3]
#
# ==================== Epoch 108 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8461  |  Pixel: 5.9010  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2811
#   ⚖️  [Discriminator] |  Real: 0.0861  |  Fake: 0.0680
#   📊 [Metrics Avg]   |  PSNR: 33.81 dB  |  Time: 59.6s  |  LR: 0.000182
# ------------------------------------------------------------
#
# Epoch 109: 100%|████████| 150/150 [00:59<00:00,  2.53it/s, L1=4.893, PSNR=100.0]
#
# ==================== Epoch 109 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8306  |  Pixel: 6.1237  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2945
#   ⚖️  [Discriminator] |  Real: 0.0901  |  Fake: 0.0811
#   📊 [Metrics Avg]   |  PSNR: 34.67 dB  |  Time: 59.3s  |  LR: 0.000180
# ------------------------------------------------------------
#
# Epoch 110: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=9.866, PSNR=30.7]
#
# ==================== Epoch 110 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8465  |  Pixel: 6.0513  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2876
#   ⚖️  [Discriminator] |  Real: 0.0854  |  Fake: 0.0771
#   📊 [Metrics Avg]   |  PSNR: 34.06 dB  |  Time: 58.7s  |  LR: 0.000178
# ------------------------------------------------------------
#
# Epoch 111: 100%|█████████| 150/150 [00:59<00:00,  2.53it/s, L1=9.538, PSNR=52.5]
#
# ==================== Epoch 111 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8669  |  Pixel: 6.1589  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2994
#   ⚖️  [Discriminator] |  Real: 0.0693  |  Fake: 0.0602
#   📊 [Metrics Avg]   |  PSNR: 33.67 dB  |  Time: 59.4s  |  LR: 0.000176
# ------------------------------------------------------------
#
# Epoch 112: 100%|█████████| 150/150 [00:59<00:00,  2.53it/s, L1=6.647, PSNR=28.5]
#
# ==================== Epoch 112 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8828  |  Pixel: 6.1205  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2952
#   ⚖️  [Discriminator] |  Real: 0.0683  |  Fake: 0.0556
#   📊 [Metrics Avg]   |  PSNR: 33.59 dB  |  Time: 59.5s  |  LR: 0.000174
# ------------------------------------------------------------
#
# Epoch 113: 100%|█████████| 150/150 [01:00<00:00,  2.49it/s, L1=3.137, PSNR=34.7]
#
# ==================== Epoch 113 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8537  |  Pixel: 6.0769  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2918
#   ⚖️  [Discriminator] |  Real: 0.0801  |  Fake: 0.0682
#   📊 [Metrics Avg]   |  PSNR: 33.06 dB  |  Time: 60.3s  |  LR: 0.000172
# ------------------------------------------------------------
#
# Epoch 114: 100%|█████████| 150/150 [00:59<00:00,  2.53it/s, L1=8.934, PSNR=27.6]
#
# ==================== Epoch 114 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8685  |  Pixel: 6.2302  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2964
#   ⚖️  [Discriminator] |  Real: 0.0717  |  Fake: 0.0631
#   📊 [Metrics Avg]   |  PSNR: 33.03 dB  |  Time: 59.3s  |  LR: 0.000170
# ------------------------------------------------------------
#
# Epoch 115: 100%|█████████| 150/150 [00:59<00:00,  2.54it/s, L1=1.340, PSNR=52.0]
#
# ==================== Epoch 115 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8654  |  Pixel: 6.0718  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2907
#   ⚖️  [Discriminator] |  Real: 0.0747  |  Fake: 0.0613
#   📊 [Metrics Avg]   |  PSNR: 35.19 dB  |  Time: 59.1s  |  LR: 0.000168
# ------------------------------------------------------------
#
# Epoch 116: 100%|█████████| 150/150 [00:58<00:00,  2.55it/s, L1=8.333, PSNR=28.7]
#
# ==================== Epoch 116 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8496  |  Pixel: 5.9768  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2873
#   ⚖️  [Discriminator] |  Real: 0.0815  |  Fake: 0.0675
#   📊 [Metrics Avg]   |  PSNR: 35.72 dB  |  Time: 58.9s  |  LR: 0.000166
# ------------------------------------------------------------
#
# Epoch 117: 100%|████████| 150/150 [01:04<00:00,  2.32it/s, L1=4.532, PSNR=100.0]
#
# ==================== Epoch 117 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8577  |  Pixel: 5.9325  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2838
#   ⚖️  [Discriminator] |  Real: 0.0754  |  Fake: 0.0670
#   📊 [Metrics Avg]   |  PSNR: 35.87 dB  |  Time: 64.9s  |  LR: 0.000164
# ------------------------------------------------------------
#
# Epoch 118: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=6.282, PSNR=26.5]
#
# ==================== Epoch 118 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8552  |  Pixel: 5.8742  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2809
#   ⚖️  [Discriminator] |  Real: 0.0762  |  Fake: 0.0667
#   📊 [Metrics Avg]   |  PSNR: 34.70 dB  |  Time: 59.8s  |  LR: 0.000162
# ------------------------------------------------------------
#
# Epoch 119: 100%|████████| 150/150 [00:56<00:00,  2.65it/s, L1=6.088, PSNR=100.0]
#
# ==================== Epoch 119 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8964  |  Pixel: 6.3008  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3049
#   ⚖️  [Discriminator] |  Real: 0.0547  |  Fake: 0.0494
#   📊 [Metrics Avg]   |  PSNR: 32.14 dB  |  Time: 56.7s  |  LR: 0.000160
# ------------------------------------------------------------
#
# Epoch 120: 100%|████████| 150/150 [00:56<00:00,  2.67it/s, L1=2.102, PSNR=100.0]
#
# ==================== Epoch 120 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8369  |  Pixel: 6.0010  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2873
#   ⚖️  [Discriminator] |  Real: 0.0865  |  Fake: 0.0795
#   📊 [Metrics Avg]   |  PSNR: 35.52 dB  |  Time: 56.4s  |  LR: 0.000158
# ------------------------------------------------------------
#
# Epoch 121: 100%|█████████| 150/150 [00:56<00:00,  2.64it/s, L1=5.196, PSNR=41.6]
#
# ==================== Epoch 121 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8857  |  Pixel: 6.0301  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2908
#   ⚖️  [Discriminator] |  Real: 0.0617  |  Fake: 0.0481
#   📊 [Metrics Avg]   |  PSNR: 34.38 dB  |  Time: 56.9s  |  LR: 0.000156
# ------------------------------------------------------------
#
# Epoch 122: 100%|█████████| 150/150 [00:56<00:00,  2.66it/s, L1=1.400, PSNR=50.7]
#
# ==================== Epoch 122 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9127  |  Pixel: 6.2176  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.3017
#   ⚖️  [Discriminator] |  Real: 0.0539  |  Fake: 0.0411
#   📊 [Metrics Avg]   |  PSNR: 34.19 dB  |  Time: 56.4s  |  LR: 0.000154
# ------------------------------------------------------------
#
# Epoch 123: 100%|█████████| 150/150 [00:57<00:00,  2.60it/s, L1=7.736, PSNR=27.9]
#
# ==================== Epoch 123 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8796  |  Pixel: 6.0506  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2908
#   ⚖️  [Discriminator] |  Real: 0.0613  |  Fake: 0.0542
#   📊 [Metrics Avg]   |  PSNR: 35.39 dB  |  Time: 57.7s  |  LR: 0.000152
# ------------------------------------------------------------
#
# Epoch 124: 100%|█████████| 150/150 [00:56<00:00,  2.67it/s, L1=4.467, PSNR=27.9]
#
# ==================== Epoch 124 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8532  |  Pixel: 5.8106  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2784
#   ⚖️  [Discriminator] |  Real: 0.1455  |  Fake: 0.1291
#   📊 [Metrics Avg]   |  PSNR: 34.17 dB  |  Time: 56.3s  |  LR: 0.000150
# ------------------------------------------------------------
#
# Epoch 125: 100%|█████████| 150/150 [00:55<00:00,  2.68it/s, L1=5.142, PSNR=30.8]
#
# ==================== Epoch 125 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8865  |  Pixel: 5.9588  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2871
#   ⚖️  [Discriminator] |  Real: 0.0565  |  Fake: 0.0496
#   📊 [Metrics Avg]   |  PSNR: 35.99 dB  |  Time: 56.0s  |  LR: 0.000149
# ------------------------------------------------------------
#
# Epoch 126: 100%|█████████| 150/150 [00:55<00:00,  2.70it/s, L1=8.781, PSNR=24.7]
#
# ==================== Epoch 126 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8910  |  Pixel: 6.1719  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2955
#   ⚖️  [Discriminator] |  Real: 0.0571  |  Fake: 0.0449
#   📊 [Metrics Avg]   |  PSNR: 34.84 dB  |  Time: 55.7s  |  LR: 0.000147
# ------------------------------------------------------------
#
# Epoch 127: 100%|█████████| 150/150 [00:56<00:00,  2.64it/s, L1=5.784, PSNR=33.4]
#
# ==================== Epoch 127 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8751  |  Pixel: 5.8588  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2844
#   ⚖️  [Discriminator] |  Real: 0.0629  |  Fake: 0.0583
#   📊 [Metrics Avg]   |  PSNR: 35.00 dB  |  Time: 56.9s  |  LR: 0.000145
# ------------------------------------------------------------
#
# Epoch 128: 100%|█████████| 150/150 [00:59<00:00,  2.52it/s, L1=2.102, PSNR=34.6]
#
# ==================== Epoch 128 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8197  |  Pixel: 6.1655  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2967
#   ⚖️  [Discriminator] |  Real: 0.0861  |  Fake: 0.0766
#   📊 [Metrics Avg]   |  PSNR: 33.75 dB  |  Time: 59.6s  |  LR: 0.000143
# ------------------------------------------------------------
#
# Epoch 129: 100%|█████████| 150/150 [00:56<00:00,  2.65it/s, L1=6.861, PSNR=36.4]
#
# ==================== Epoch 129 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8727  |  Pixel: 6.2328  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2993
#   ⚖️  [Discriminator] |  Real: 0.0610  |  Fake: 0.0470
#   📊 [Metrics Avg]   |  PSNR: 33.11 dB  |  Time: 56.6s  |  LR: 0.000141
# ------------------------------------------------------------
#
# Epoch 130: 100%|█████████| 150/150 [00:57<00:00,  2.61it/s, L1=8.830, PSNR=33.8]
#
# ==================== Epoch 130 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9013  |  Pixel: 6.1630  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2982
#   ⚖️  [Discriminator] |  Real: 0.0609  |  Fake: 0.0552
#   📊 [Metrics Avg]   |  PSNR: 32.69 dB  |  Time: 57.6s  |  LR: 0.000139
# ------------------------------------------------------------
#
# Epoch 131: 100%|█████████| 150/150 [05:35<00:00,  2.23s/it, L1=6.848, PSNR=29.3]
#
# ==================== Epoch 131 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8848  |  Pixel: 6.0806  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2935
#   ⚖️  [Discriminator] |  Real: 0.0554  |  Fake: 0.0459
#   📊 [Metrics Avg]   |  PSNR: 34.76 dB  |  Time: 335.3s  |  LR: 0.000137
# ------------------------------------------------------------
#
# Epoch 132: 100%|█████████| 150/150 [01:14<00:00,  2.01it/s, L1=6.394, PSNR=27.1]
#
# ==================== Epoch 132 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8949  |  Pixel: 6.2746  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.3068
#   ⚖️  [Discriminator] |  Real: 0.0555  |  Fake: 0.0479
#   📊 [Metrics Avg]   |  PSNR: 33.62 dB  |  Time: 74.7s  |  LR: 0.000135
# ------------------------------------------------------------
#
# Epoch 133: 100%|█████████| 150/150 [02:13<00:00,  1.12it/s, L1=9.062, PSNR=25.6]
#
# ==================== Epoch 133 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8988  |  Pixel: 6.0075  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2915
#   ⚖️  [Discriminator] |  Real: 0.0529  |  Fake: 0.0541
#   📊 [Metrics Avg]   |  PSNR: 32.71 dB  |  Time: 133.9s  |  LR: 0.000133
# ------------------------------------------------------------
#
# Epoch 134: 100%|█████████| 150/150 [02:48<00:00,  1.13s/it, L1=4.001, PSNR=32.0]
#
# ==================== Epoch 134 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8973  |  Pixel: 6.0642  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2960
#   ⚖️  [Discriminator] |  Real: 0.0564  |  Fake: 0.0506
#   📊 [Metrics Avg]   |  PSNR: 33.68 dB  |  Time: 169.0s  |  LR: 0.000131
# ------------------------------------------------------------
#
# Epoch 135: 100%|█████████| 150/150 [03:49<00:00,  1.53s/it, L1=7.253, PSNR=28.5]
#
# ==================== Epoch 135 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8930  |  Pixel: 5.6820  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2773
#   ⚖️  [Discriminator] |  Real: 0.0569  |  Fake: 0.0495
#   📊 [Metrics Avg]   |  PSNR: 34.34 dB  |  Time: 229.4s  |  LR: 0.000129
# ------------------------------------------------------------
#
# Epoch 136: 100%|█████████| 150/150 [02:38<00:00,  1.06s/it, L1=3.286, PSNR=32.8]
#
# ==================== Epoch 136 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9001  |  Pixel: 5.8789  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2860
#   ⚖️  [Discriminator] |  Real: 0.0575  |  Fake: 0.0426
#   📊 [Metrics Avg]   |  PSNR: 36.14 dB  |  Time: 158.7s  |  LR: 0.000127
# ------------------------------------------------------------
#
# Epoch 137:  47%|████▋     | 70/150 [01:17<02:11,  1.65s/it, L1=4.214, PSNR=35.3]^C

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results

  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results 
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 45_L1_Max_500_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results 


# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 37_Base_Sharp1.5_FFL0.1_BG20  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 37_Base_Sharp1.5_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.21 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/37_Base_Sharp1.5_FFL0.1_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 38_Mild_Sharp1.5_FFL0.1_BG05  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 38_Mild_Sharp1.5_FFL0.1_BG05
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/38_Mild_Sharp1.5_FFL0.1_BG05/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.03 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/38_Mild_Sharp1.5_FFL0.1_BG05
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 39_Hard_Sharp1.5_FFL0.1_BG50  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 39_Hard_Sharp1.5_FFL0.1_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/39_Hard_Sharp1.5_FFL0.1_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.80 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/39_Hard_Sharp1.5_FFL0.1_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 40_FFL_Mid_Sharp1.5_FFL0.5_BG20	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 40_FFL_Mid_Sharp1.5_FFL0.5_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/40_FFL_Mid_Sharp1.5_FFL0.5_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 48.80 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/40_FFL_Mid_Sharp1.5_FFL0.5_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 41_FFL_Max_Sharp1.5_FFL1.0_BG20	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 41_FFL_Max_Sharp1.5_FFL1.0_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/41_FFL_Max_Sharp1.5_FFL1.0_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.29 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/41_FFL_Max_Sharp1.5_FFL1.0_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 42_Sharp2.0_FFL0.1_BG20       	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 42_Sharp2.0_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/42_Sharp2.0_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.52 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/42_Sharp2.0_FFL0.1_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 43_Soft1.2_FFL0.1_BG50        	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 43_Soft1.2_FFL0.1_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/43_Soft1.2_FFL0.1_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.17 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/43_Soft1.2_FFL0.1_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 44_Nuclear_Sharp1.5_FFL1.0_BG50	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 44_Nuclear_Sharp1.5_FFL1.0_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/44_Nuclear_Sharp1.5_FFL1.0_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.95 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/44_Nuclear_Sharp1.5_FFL1.0_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 45_L1_Max_500_BG20            	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 45_L1_Max_500_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/45_L1_Max_500_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.65 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/45_L1_Max_500_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 46_NoDil_Sharp1.5_FFL0.1_BG20 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 46_NoDil_Sharp1.5_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.84 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/46_NoDil_Sharp1.5_FFL0.1_BG20
