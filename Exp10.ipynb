# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --lambda_ssim 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 5.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.5 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 1.0 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 2.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.2 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 1.0 \
  --lambda_bg 50.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 45_L1_Max_500_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 500.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0

# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 30 \
  --n_epochs_decay 20 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 30                            	[default: 100]
#            n_epochs_decay: 20                            	[default: 100]
#                n_layers_D: 3
#                      name: 37_Base_Sharp1.5_FFL0.1_BG20  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 37_Base_Sharp1.5_FFL0.1_BG20
# 📂 数据路径: /home/liujia/g_linux/Simu_1channel/
# ================================================================================
#
# Dataset V7 (Final). Found 300 pairs.
# dataset [UltrasoundDataset] was created
# model [AuganModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 1: 100%|███████████| 150/150 [01:15<00:00,  1.98it/s, L1=2.163, PSNR=56.5]
#
# ==================== Epoch 1 Summary ====================
#   🎨 [Generator Avg] |  GAN: 2.6703  |  Pixel: 14.9951  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0052  |  BG: 0.5916
#   ⚖️  [Discriminator] |  Real: 2.2185  |  Fake: 1.9571
#   📊 [Metrics Avg]   |  PSNR: 26.97 dB  |  Time: 76.0s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 2: 100%|██████████| 150/150 [01:00<00:00,  2.48it/s, L1=10.059, PSNR=35.5]
#
# ==================== Epoch 2 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9898  |  Pixel: 11.6597  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0052  |  BG: 0.2816
#   ⚖️  [Discriminator] |  Real: 0.4518  |  Fake: 0.3518
#   📊 [Metrics Avg]   |  PSNR: 28.09 dB  |  Time: 60.7s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 3: 100%|███████████| 150/150 [00:59<00:00,  2.51it/s, L1=5.300, PSNR=22.5]
#
# ==================== Epoch 3 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.6303  |  Pixel: 10.8726  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0045  |  BG: 0.3384
#   ⚖️  [Discriminator] |  Real: 0.4592  |  Fake: 0.3635
#   📊 [Metrics Avg]   |  PSNR: 27.15 dB  |  Time: 59.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 4: 100%|███████████| 150/150 [01:02<00:00,  2.39it/s, L1=5.694, PSNR=34.2]
#
# ==================== Epoch 4 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4689  |  Pixel: 9.2517  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0039  |  BG: 0.3204
#   ⚖️  [Discriminator] |  Real: 0.3909  |  Fake: 0.3403
#   📊 [Metrics Avg]   |  PSNR: 28.71 dB  |  Time: 62.8s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 5: 100%|███████████| 150/150 [01:01<00:00,  2.45it/s, L1=1.276, PSNR=60.0]
#
# ==================== Epoch 5 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4264  |  Pixel: 8.7378  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0036  |  BG: 0.3126
#   ⚖️  [Discriminator] |  Real: 0.3692  |  Fake: 0.3278
#   📊 [Metrics Avg]   |  PSNR: 29.60 dB  |  Time: 61.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 6: 100%|███████████| 150/150 [00:58<00:00,  2.58it/s, L1=7.339, PSNR=25.3]
#
# ==================== Epoch 6 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4608  |  Pixel: 8.4921  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0035  |  BG: 0.3214
#   ⚖️  [Discriminator] |  Real: 0.3744  |  Fake: 0.3512
#   📊 [Metrics Avg]   |  PSNR: 28.81 dB  |  Time: 58.3s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 7: 100%|██████████| 150/150 [00:56<00:00,  2.66it/s, L1=0.108, PSNR=100.0]
#
# ==================== Epoch 7 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4489  |  Pixel: 7.8746  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0034  |  BG: 0.3006
#   ⚖️  [Discriminator] |  Real: 0.3768  |  Fake: 0.3374
#   📊 [Metrics Avg]   |  PSNR: 32.43 dB  |  Time: 56.5s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 8: 100%|███████████| 150/150 [00:56<00:00,  2.66it/s, L1=8.182, PSNR=32.2]
#
# ==================== Epoch 8 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4209  |  Pixel: 7.8919  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0034  |  BG: 0.3073
#   ⚖️  [Discriminator] |  Real: 0.3226  |  Fake: 0.3057
#   📊 [Metrics Avg]   |  PSNR: 30.68 dB  |  Time: 56.6s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 9: 100%|███████████| 150/150 [00:57<00:00,  2.62it/s, L1=1.968, PSNR=34.2]
#
# ==================== Epoch 9 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4861  |  Pixel: 7.6429  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0033  |  BG: 0.3025
#   ⚖️  [Discriminator] |  Real: 0.3763  |  Fake: 0.3446
#   📊 [Metrics Avg]   |  PSNR: 33.89 dB  |  Time: 57.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 10: 100%|██████████| 150/150 [00:56<00:00,  2.66it/s, L1=4.504, PSNR=45.4]
#
# ==================== Epoch 10 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4327  |  Pixel: 7.4774  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0033  |  BG: 0.2991
#   ⚖️  [Discriminator] |  Real: 0.3582  |  Fake: 0.3336
#   📊 [Metrics Avg]   |  PSNR: 32.84 dB  |  Time: 56.4s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 11: 100%|██████████| 150/150 [00:57<00:00,  2.63it/s, L1=8.225, PSNR=33.3]
#
# ==================== Epoch 11 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.4146  |  Pixel: 7.6944  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0034  |  BG: 0.3096
#   ⚖️  [Discriminator] |  Real: 0.3214  |  Fake: 0.2951
#   📊 [Metrics Avg]   |  PSNR: 30.32 dB  |  Time: 57.1s  |  LR: 0.000200
# ------------------------------------------------------------
#
# Epoch 12:  19%|██▏        | 29/150 [00:11<00:53,  2.28it/s, L1=7.092, PSNR=24.6]

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results

  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results 
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 45_L1_Max_500_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results 


# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  ----results_dir /mnt/g/train_data/results
