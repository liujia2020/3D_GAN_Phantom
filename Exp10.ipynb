# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --lambda_ssim 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 5.0 
  
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.5 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 1.0 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 2.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0
  
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.2 \
  --lambda_ffl 0.1 \
  --lambda_bg 50.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 51                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 37_Base_Sharp1.5_FFL0.1_BG20  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 37_Base_Sharp1.5_FFL0.1_BG20
# 📂 数据路径: /home/liujia/g_linux/Simu_1channel/
# ================================================================================
#
# Dataset V7 (Final). Found 300 pairs.
# dataset [UltrasoundDataset] was created
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 51:   1%|▏          | 2/150 [00:23<25:42, 10.42s/it, L1=11.611, PSNR=23.5]^C

# %%
# !python train.py \
#   --dataroot /home/liujia/g_linux/Simu_1channel/ \
#   --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
#   --checkpoints_dir /mnt/g/train_data/checkpoints \
#   --dir_lq Recon_LQ_03 \
#   --dir_sq Recon_SQ_75 \
#   --model augan \
#   --netG res_unet_3d \
#   --input_nc 1 \
#   --output_nc 1 \
#   --batch_size 2 \
#   --patch_size_d 128 \
#   --patch_size_h 64 \
#   --patch_size_w 64 \
#   --lambda_pixel 200.0 \
#   --lambda_gan 10.0 \
#   --lambda_perceptual 0.0 \
#   --norm batch \
#   --no_flip \
#   --use_attention \
#   --use_dilation \
#   --gpu_ids 0 \
#   --n_epochs 100 \
#   --n_epochs_decay 100 \
#   --attn_temp 1.5 \
#   --lambda_ffl 1.0 \
#   --lambda_bg 50.0 \
#   --continue_train \
#   --epoch_count 56
      
  
# !python train.py \
#   --dataroot /home/liujia/g_linux/Simu_1channel/ \
#   --name 45_L1_Max_500_BG20 \
#   --checkpoints_dir /mnt/g/train_data/checkpoints \
#   --dir_lq Recon_LQ_03 \
#   --dir_sq Recon_SQ_75 \
#   --model augan \
#   --netG res_unet_3d \
#   --input_nc 1 \
#   --output_nc 1 \
#   --batch_size 2 \
#   --patch_size_d 128 \
#   --patch_size_h 64 \
#   --patch_size_w 64 \
#   --lambda_pixel 500.0 \
#   --lambda_gan 10.0 \
#   --lambda_perceptual 0.0 \
#   --norm batch \
#   --no_flip \
#   --use_attention \
#   --use_dilation \
#   --gpu_ids 0 \
#   --n_epochs 100 \
#   --n_epochs_decay 100 \
#   --attn_temp 1.5 \
#   --lambda_ffl 0.1 \
#   --lambda_bg 20.0

# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 1.5 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --continue_train \
  --epoch_count 136
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 136                           	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                 lambda_bg: 20.0                          	[default: 0.0]
#               lambda_edge: 0.0
#                lambda_ffl: 0.1                           	[default: 0.0]
#                lambda_gan: 10.0                          	[default: 1.0]
#         lambda_perceptual: 0.0
#              lambda_pixel: 200.0                         	[default: 100.0]
#               lambda_ssim: 0.0
#                 lambda_tv: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                        lr: 0.0002
#                lr_d_ratio: 1.0
#            lr_decay_iters: 50
#                 lr_policy: linear
#                     model: augan                         	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: 46_NoDil_Sharp1.5_FFL0.1_BG20 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 128                           	[default: 64]
#              patch_size_h: 64                            	[default: 128]
#              patch_size_w: 64                            	[default: 128]
#                     phase: train
#                 pool_size: 50
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 训练启动 | 实验: 46_NoDil_Sharp1.5_FFL0.1_BG20
# 📂 数据路径: /home/liujia/g_linux/Simu_1channel/
# ================================================================================
#
# Dataset V7 (Final). Found 300 pairs.
# dataset [UltrasoundDataset] was created
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_D.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# [Network D] Total number of parameters : 11.053 M
# -----------------------------------------------
# Epoch 136: 100%|████████| 150/150 [01:19<00:00,  1.88it/s, L1=11.435, PSNR=24.9]
#
# ==================== Epoch 136 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8940  |  Pixel: 5.7328  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2782
#   ⚖️  [Discriminator] |  Real: 0.0568  |  Fake: 0.0525
#   📊 [Metrics Avg]   |  PSNR: 35.87 dB  |  Time: 79.7s  |  LR: 0.000127
# ------------------------------------------------------------
#
# Epoch 137: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=6.375, PSNR=27.2]
#
# ==================== Epoch 137 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8748  |  Pixel: 5.8930  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2892
#   ⚖️  [Discriminator] |  Real: 0.0665  |  Fake: 0.0635
#   📊 [Metrics Avg]   |  PSNR: 35.61 dB  |  Time: 59.9s  |  LR: 0.000125
# ------------------------------------------------------------
#
# Epoch 138: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=4.008, PSNR=27.9]
#
# ==================== Epoch 138 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9111  |  Pixel: 5.7720  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2835
#   ⚖️  [Discriminator] |  Real: 0.0459  |  Fake: 0.0362
#   📊 [Metrics Avg]   |  PSNR: 33.80 dB  |  Time: 59.8s  |  LR: 0.000123
# ------------------------------------------------------------
#
# Epoch 139: 100%|█████████| 150/150 [01:00<00:00,  2.50it/s, L1=1.249, PSNR=53.3]
#
# ==================== Epoch 139 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9075  |  Pixel: 5.9472  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2931
#   ⚖️  [Discriminator] |  Real: 0.0530  |  Fake: 0.0478
#   📊 [Metrics Avg]   |  PSNR: 33.34 dB  |  Time: 60.1s  |  LR: 0.000121
# ------------------------------------------------------------
#
# Epoch 140: 100%|████████| 150/150 [01:00<00:00,  2.46it/s, L1=12.542, PSNR=25.5]
#
# ==================== Epoch 140 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8912  |  Pixel: 5.9793  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2905
#   ⚖️  [Discriminator] |  Real: 0.0621  |  Fake: 0.0537
#   📊 [Metrics Avg]   |  PSNR: 34.14 dB  |  Time: 61.1s  |  LR: 0.000119
# ------------------------------------------------------------
#
# Epoch 141: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=9.453, PSNR=26.6]
#
# ==================== Epoch 141 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9052  |  Pixel: 5.8953  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2879
#   ⚖️  [Discriminator] |  Real: 0.0502  |  Fake: 0.0427
#   📊 [Metrics Avg]   |  PSNR: 33.63 dB  |  Time: 58.8s  |  LR: 0.000117
# ------------------------------------------------------------
#
# Epoch 142: 100%|█████████| 150/150 [00:57<00:00,  2.62it/s, L1=8.835, PSNR=30.0]
#
# ==================== Epoch 142 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9185  |  Pixel: 5.9508  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2916
#   ⚖️  [Discriminator] |  Real: 0.0443  |  Fake: 0.0359
#   📊 [Metrics Avg]   |  PSNR: 34.27 dB  |  Time: 57.3s  |  LR: 0.000115
# ------------------------------------------------------------
#
# Epoch 143: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=7.924, PSNR=26.9]
#
# ==================== Epoch 143 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9157  |  Pixel: 5.9991  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2943
#   ⚖️  [Discriminator] |  Real: 0.0431  |  Fake: 0.0413
#   📊 [Metrics Avg]   |  PSNR: 33.58 dB  |  Time: 58.4s  |  LR: 0.000113
# ------------------------------------------------------------
#
# Epoch 144: 100%|█████████| 150/150 [00:56<00:00,  2.63it/s, L1=5.069, PSNR=39.9]
#
# ==================== Epoch 144 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9119  |  Pixel: 5.6904  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2761
#   ⚖️  [Discriminator] |  Real: 0.0523  |  Fake: 0.0467
#   📊 [Metrics Avg]   |  PSNR: 33.50 dB  |  Time: 57.1s  |  LR: 0.000111
# ------------------------------------------------------------
#
# Epoch 145: 100%|█████████| 150/150 [00:56<00:00,  2.67it/s, L1=5.109, PSNR=26.7]
#
# ==================== Epoch 145 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9162  |  Pixel: 5.9469  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2929
#   ⚖️  [Discriminator] |  Real: 0.0447  |  Fake: 0.0407
#   📊 [Metrics Avg]   |  PSNR: 35.07 dB  |  Time: 56.3s  |  LR: 0.000109
# ------------------------------------------------------------
#
# Epoch 146: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=5.693, PSNR=43.5]
#
# ==================== Epoch 146 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8634  |  Pixel: 5.6037  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2783
#   ⚖️  [Discriminator] |  Real: 0.0640  |  Fake: 0.0543
#   📊 [Metrics Avg]   |  PSNR: 34.34 dB  |  Time: 58.5s  |  LR: 0.000107
# ------------------------------------------------------------
#
# Epoch 147: 100%|█████████| 150/150 [00:58<00:00,  2.58it/s, L1=7.413, PSNR=25.6]
#
# ==================== Epoch 147 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9342  |  Pixel: 5.7675  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2843
#   ⚖️  [Discriminator] |  Real: 0.0436  |  Fake: 0.0378
#   📊 [Metrics Avg]   |  PSNR: 34.79 dB  |  Time: 58.1s  |  LR: 0.000105
# ------------------------------------------------------------
#
# Epoch 148: 100%|█████████| 150/150 [01:01<00:00,  2.44it/s, L1=8.890, PSNR=28.0]
#
# ==================== Epoch 148 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9113  |  Pixel: 5.7718  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2835
#   ⚖️  [Discriminator] |  Real: 0.0503  |  Fake: 0.0454
#   📊 [Metrics Avg]   |  PSNR: 34.86 dB  |  Time: 61.6s  |  LR: 0.000103
# ------------------------------------------------------------
#
# Epoch 149: 100%|█████████| 150/150 [01:01<00:00,  2.42it/s, L1=5.234, PSNR=29.4]
#
# ==================== Epoch 149 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9132  |  Pixel: 5.7115  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2816
#   ⚖️  [Discriminator] |  Real: 0.0464  |  Fake: 0.0374
#   📊 [Metrics Avg]   |  PSNR: 33.37 dB  |  Time: 62.1s  |  LR: 0.000101
# ------------------------------------------------------------
#
# Epoch 150: 100%|█████████| 150/150 [01:00<00:00,  2.48it/s, L1=2.571, PSNR=39.3]
#
# ==================== Epoch 150 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8987  |  Pixel: 5.9927  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2955
#   ⚖️  [Discriminator] |  Real: 0.0489  |  Fake: 0.0485
#   📊 [Metrics Avg]   |  PSNR: 34.30 dB  |  Time: 60.5s  |  LR: 0.000099
# ------------------------------------------------------------
#
# Epoch 151: 100%|█████████| 150/150 [01:01<00:00,  2.42it/s, L1=8.476, PSNR=26.6]
#
# ==================== Epoch 151 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9121  |  Pixel: 6.0371  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2983
#   ⚖️  [Discriminator] |  Real: 0.0464  |  Fake: 0.0372
#   📊 [Metrics Avg]   |  PSNR: 35.49 dB  |  Time: 62.2s  |  LR: 0.000097
# ------------------------------------------------------------
#
# Epoch 152: 100%|█████████| 150/150 [01:05<00:00,  2.29it/s, L1=4.436, PSNR=25.9]
#
# ==================== Epoch 152 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9297  |  Pixel: 5.6541  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2808
#   ⚖️  [Discriminator] |  Real: 0.0392  |  Fake: 0.0335
#   📊 [Metrics Avg]   |  PSNR: 34.73 dB  |  Time: 65.6s  |  LR: 0.000095
# ------------------------------------------------------------
#
# Epoch 153: 100%|█████████| 150/150 [00:55<00:00,  2.70it/s, L1=6.989, PSNR=25.9]
#
# ==================== Epoch 153 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9048  |  Pixel: 5.6602  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2787
#   ⚖️  [Discriminator] |  Real: 0.0448  |  Fake: 0.0407
#   📊 [Metrics Avg]   |  PSNR: 34.78 dB  |  Time: 55.6s  |  LR: 0.000093
# ------------------------------------------------------------
#
# Epoch 154: 100%|████████| 150/150 [00:56<00:00,  2.64it/s, L1=13.231, PSNR=24.1]
#
# ==================== Epoch 154 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9112  |  Pixel: 5.8656  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2916
#   ⚖️  [Discriminator] |  Real: 0.0429  |  Fake: 0.0392
#   📊 [Metrics Avg]   |  PSNR: 34.20 dB  |  Time: 56.8s  |  LR: 0.000091
# ------------------------------------------------------------
#
# Epoch 155: 100%|█████████| 150/150 [00:55<00:00,  2.71it/s, L1=8.025, PSNR=28.8]
#
# ==================== Epoch 155 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9140  |  Pixel: 5.8794  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2922
#   ⚖️  [Discriminator] |  Real: 0.0446  |  Fake: 0.0352
#   📊 [Metrics Avg]   |  PSNR: 35.37 dB  |  Time: 55.5s  |  LR: 0.000089
# ------------------------------------------------------------
#
# Epoch 156: 100%|█████████| 150/150 [00:55<00:00,  2.70it/s, L1=4.177, PSNR=29.8]
#
# ==================== Epoch 156 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.8954  |  Pixel: 5.6674  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2822
#   ⚖️  [Discriminator] |  Real: 0.0488  |  Fake: 0.0448
#   📊 [Metrics Avg]   |  PSNR: 37.34 dB  |  Time: 55.7s  |  LR: 0.000087
# ------------------------------------------------------------
#
# Epoch 157: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=2.197, PSNR=30.3]
#
# ==================== Epoch 157 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9482  |  Pixel: 5.6697  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2846
#   ⚖️  [Discriminator] |  Real: 0.0314  |  Fake: 0.0280
#   📊 [Metrics Avg]   |  PSNR: 32.77 dB  |  Time: 58.8s  |  LR: 0.000085
# ------------------------------------------------------------
#
# Epoch 158: 100%|█████████| 150/150 [00:59<00:00,  2.50it/s, L1=2.253, PSNR=30.0]
#
# ==================== Epoch 158 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9386  |  Pixel: 5.7506  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2855
#   ⚖️  [Discriminator] |  Real: 0.0314  |  Fake: 0.0281
#   📊 [Metrics Avg]   |  PSNR: 37.30 dB  |  Time: 60.0s  |  LR: 0.000083
# ------------------------------------------------------------
#
# Epoch 159: 100%|█████████| 150/150 [01:02<00:00,  2.38it/s, L1=5.768, PSNR=31.6]
#
# ==================== Epoch 159 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9325  |  Pixel: 5.6468  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2794
#   ⚖️  [Discriminator] |  Real: 0.0325  |  Fake: 0.0305
#   📊 [Metrics Avg]   |  PSNR: 35.84 dB  |  Time: 63.0s  |  LR: 0.000081
# ------------------------------------------------------------
#
# Epoch 160: 100%|█████████| 150/150 [01:00<00:00,  2.48it/s, L1=4.652, PSNR=28.0]
#
# ==================== Epoch 160 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9258  |  Pixel: 5.6149  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2778
#   ⚖️  [Discriminator] |  Real: 0.0419  |  Fake: 0.0333
#   📊 [Metrics Avg]   |  PSNR: 34.51 dB  |  Time: 60.6s  |  LR: 0.000079
# ------------------------------------------------------------
#
# Epoch 161: 100%|████████| 150/150 [01:04<00:00,  2.33it/s, L1=2.280, PSNR=100.0]
#
# ==================== Epoch 161 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9427  |  Pixel: 5.3762  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2683
#   ⚖️  [Discriminator] |  Real: 0.0319  |  Fake: 0.0280
#   📊 [Metrics Avg]   |  PSNR: 34.71 dB  |  Time: 64.6s  |  LR: 0.000077
# ------------------------------------------------------------
#
# Epoch 162: 100%|█████████| 150/150 [01:03<00:00,  2.36it/s, L1=7.472, PSNR=32.4]
#
# ==================== Epoch 162 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9369  |  Pixel: 5.5304  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2746
#   ⚖️  [Discriminator] |  Real: 0.0326  |  Fake: 0.0225
#   📊 [Metrics Avg]   |  PSNR: 33.87 dB  |  Time: 63.7s  |  LR: 0.000075
# ------------------------------------------------------------
#
# Epoch 163: 100%|█████████| 150/150 [01:02<00:00,  2.40it/s, L1=5.147, PSNR=43.9]
#
# ==================== Epoch 163 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9509  |  Pixel: 5.6839  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2832
#   ⚖️  [Discriminator] |  Real: 0.0263  |  Fake: 0.0228
#   📊 [Metrics Avg]   |  PSNR: 34.79 dB  |  Time: 62.7s  |  LR: 0.000073
# ------------------------------------------------------------
#
# Epoch 164: 100%|█████████| 150/150 [01:01<00:00,  2.43it/s, L1=7.030, PSNR=26.3]
#
# ==================== Epoch 164 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9494  |  Pixel: 5.7731  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2868
#   ⚖️  [Discriminator] |  Real: 0.0323  |  Fake: 0.0304
#   📊 [Metrics Avg]   |  PSNR: 33.77 dB  |  Time: 61.8s  |  LR: 0.000071
# ------------------------------------------------------------
#
# Epoch 165: 100%|█████████| 150/150 [01:00<00:00,  2.46it/s, L1=4.659, PSNR=26.9]
#
# ==================== Epoch 165 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9414  |  Pixel: 5.8460  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2903
#   ⚖️  [Discriminator] |  Real: 0.0287  |  Fake: 0.0259
#   📊 [Metrics Avg]   |  PSNR: 33.36 dB  |  Time: 61.0s  |  LR: 0.000069
# ------------------------------------------------------------
#
# Epoch 166: 100%|█████████| 150/150 [01:02<00:00,  2.39it/s, L1=8.504, PSNR=29.3]
#
# ==================== Epoch 166 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9319  |  Pixel: 5.5776  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2776
#   ⚖️  [Discriminator] |  Real: 0.0332  |  Fake: 0.0269
#   📊 [Metrics Avg]   |  PSNR: 33.35 dB  |  Time: 62.9s  |  LR: 0.000067
# ------------------------------------------------------------
#
# Epoch 167: 100%|█████████| 150/150 [00:58<00:00,  2.55it/s, L1=4.689, PSNR=29.0]
#
# ==================== Epoch 167 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9314  |  Pixel: 5.6187  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2841
#   ⚖️  [Discriminator] |  Real: 0.0365  |  Fake: 0.0267
#   📊 [Metrics Avg]   |  PSNR: 34.60 dB  |  Time: 58.8s  |  LR: 0.000065
# ------------------------------------------------------------
#
# Epoch 168: 100%|█████████| 150/150 [01:00<00:00,  2.46it/s, L1=3.151, PSNR=31.4]
#
# ==================== Epoch 168 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9588  |  Pixel: 5.5946  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2820
#   ⚖️  [Discriminator] |  Real: 0.0241  |  Fake: 0.0167
#   📊 [Metrics Avg]   |  PSNR: 34.48 dB  |  Time: 61.0s  |  LR: 0.000063
# ------------------------------------------------------------
#
# Epoch 169: 100%|█████████| 150/150 [01:06<00:00,  2.27it/s, L1=6.125, PSNR=29.1]
#
# ==================== Epoch 169 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9507  |  Pixel: 5.4086  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0024  |  BG: 0.2711
#   ⚖️  [Discriminator] |  Real: 0.0271  |  Fake: 0.0212
#   📊 [Metrics Avg]   |  PSNR: 34.99 dB  |  Time: 66.3s  |  LR: 0.000061
# ------------------------------------------------------------
#
# Epoch 170: 100%|█████████| 150/150 [01:02<00:00,  2.41it/s, L1=9.496, PSNR=25.4]
#
# ==================== Epoch 170 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9026  |  Pixel: 5.4436  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2721
#   ⚖️  [Discriminator] |  Real: 0.0480  |  Fake: 0.0416
#   📊 [Metrics Avg]   |  PSNR: 34.08 dB  |  Time: 62.4s  |  LR: 0.000059
# ------------------------------------------------------------
#
# Epoch 171: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=8.021, PSNR=30.0]
#
# ==================== Epoch 171 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9396  |  Pixel: 5.4920  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2791
#   ⚖️  [Discriminator] |  Real: 0.0326  |  Fake: 0.0248
#   📊 [Metrics Avg]   |  PSNR: 36.62 dB  |  Time: 60.0s  |  LR: 0.000057
# ------------------------------------------------------------
#
# Epoch 172: 100%|█████████| 150/150 [00:58<00:00,  2.58it/s, L1=3.420, PSNR=40.4]
#
# ==================== Epoch 172 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9434  |  Pixel: 5.6750  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2881
#   ⚖️  [Discriminator] |  Real: 0.0246  |  Fake: 0.0258
#   📊 [Metrics Avg]   |  PSNR: 33.72 dB  |  Time: 58.3s  |  LR: 0.000055
# ------------------------------------------------------------
#
# Epoch 173: 100%|█████████| 150/150 [00:59<00:00,  2.53it/s, L1=0.218, PSNR=38.4]
#
# ==================== Epoch 173 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9404  |  Pixel: 5.5509  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2844
#   ⚖️  [Discriminator] |  Real: 0.0260  |  Fake: 0.0201
#   📊 [Metrics Avg]   |  PSNR: 35.94 dB  |  Time: 59.4s  |  LR: 0.000053
# ------------------------------------------------------------
#
# Epoch 174: 100%|█████████| 150/150 [00:57<00:00,  2.60it/s, L1=5.537, PSNR=26.6]
#
# ==================== Epoch 174 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9527  |  Pixel: 5.7367  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2905
#   ⚖️  [Discriminator] |  Real: 0.0261  |  Fake: 0.0210
#   📊 [Metrics Avg]   |  PSNR: 32.96 dB  |  Time: 57.8s  |  LR: 0.000051
# ------------------------------------------------------------
#
# Epoch 175: 100%|█████████| 150/150 [00:57<00:00,  2.60it/s, L1=8.229, PSNR=26.4]
#
# ==================== Epoch 175 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9273  |  Pixel: 5.5090  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2781
#   ⚖️  [Discriminator] |  Real: 0.0308  |  Fake: 0.0233
#   📊 [Metrics Avg]   |  PSNR: 34.20 dB  |  Time: 57.9s  |  LR: 0.000050
# ------------------------------------------------------------
#
# Epoch 176: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=4.024, PSNR=30.3]
#
# ==================== Epoch 176 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9609  |  Pixel: 5.5934  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2806
#   ⚖️  [Discriminator] |  Real: 0.0211  |  Fake: 0.0188
#   📊 [Metrics Avg]   |  PSNR: 33.84 dB  |  Time: 58.7s  |  LR: 0.000048
# ------------------------------------------------------------
#
# Epoch 177: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=9.737, PSNR=26.7]
#
# ==================== Epoch 177 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9401  |  Pixel: 5.6702  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2891
#   ⚖️  [Discriminator] |  Real: 0.0306  |  Fake: 0.0248
#   📊 [Metrics Avg]   |  PSNR: 35.34 dB  |  Time: 58.0s  |  LR: 0.000046
# ------------------------------------------------------------
#
# Epoch 178: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=4.149, PSNR=36.9]
#
# ==================== Epoch 178 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9611  |  Pixel: 5.4373  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2737
#   ⚖️  [Discriminator] |  Real: 0.0176  |  Fake: 0.0157
#   📊 [Metrics Avg]   |  PSNR: 34.15 dB  |  Time: 59.9s  |  LR: 0.000044
# ------------------------------------------------------------
#
# Epoch 179: 100%|█████████| 150/150 [01:03<00:00,  2.38it/s, L1=5.713, PSNR=31.0]
#
# ==================== Epoch 179 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9634  |  Pixel: 5.2755  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2689
#   ⚖️  [Discriminator] |  Real: 0.0208  |  Fake: 0.0113
#   📊 [Metrics Avg]   |  PSNR: 36.27 dB  |  Time: 63.2s  |  LR: 0.000042
# ------------------------------------------------------------
#
# Epoch 180: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=8.445, PSNR=32.4]
#
# ==================== Epoch 180 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9556  |  Pixel: 5.3065  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2702
#   ⚖️  [Discriminator] |  Real: 0.0216  |  Fake: 0.0209
#   📊 [Metrics Avg]   |  PSNR: 36.35 dB  |  Time: 58.5s  |  LR: 0.000040
# ------------------------------------------------------------
#
# Epoch 181: 100%|█████████| 150/150 [00:58<00:00,  2.55it/s, L1=5.115, PSNR=44.3]
#
# ==================== Epoch 181 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9654  |  Pixel: 5.4275  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2755
#   ⚖️  [Discriminator] |  Real: 0.0182  |  Fake: 0.0137
#   📊 [Metrics Avg]   |  PSNR: 35.02 dB  |  Time: 59.0s  |  LR: 0.000038
# ------------------------------------------------------------
#
# Epoch 182: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=5.038, PSNR=28.0]
#
# ==================== Epoch 182 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9578  |  Pixel: 5.4447  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2767
#   ⚖️  [Discriminator] |  Real: 0.0210  |  Fake: 0.0153
#   📊 [Metrics Avg]   |  PSNR: 35.24 dB  |  Time: 57.9s  |  LR: 0.000036
# ------------------------------------------------------------
#
# Epoch 183: 100%|█████████| 150/150 [00:58<00:00,  2.59it/s, L1=4.965, PSNR=37.5]
#
# ==================== Epoch 183 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9496  |  Pixel: 5.4550  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2764
#   ⚖️  [Discriminator] |  Real: 0.0297  |  Fake: 0.0185
#   📊 [Metrics Avg]   |  PSNR: 33.66 dB  |  Time: 58.1s  |  LR: 0.000034
# ------------------------------------------------------------
#
# Epoch 184: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=2.956, PSNR=27.8]
#
# ==================== Epoch 184 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9533  |  Pixel: 5.4575  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2778
#   ⚖️  [Discriminator] |  Real: 0.0215  |  Fake: 0.0178
#   📊 [Metrics Avg]   |  PSNR: 35.73 dB  |  Time: 58.0s  |  LR: 0.000032
# ------------------------------------------------------------
#
# Epoch 185: 100%|█████████| 150/150 [01:02<00:00,  2.38it/s, L1=7.800, PSNR=28.6]
#
# ==================== Epoch 185 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9589  |  Pixel: 5.5346  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2815
#   ⚖️  [Discriminator] |  Real: 0.0205  |  Fake: 0.0166
#   📊 [Metrics Avg]   |  PSNR: 34.65 dB  |  Time: 63.1s  |  LR: 0.000030
# ------------------------------------------------------------
#
# Epoch 186: 100%|█████████| 150/150 [00:58<00:00,  2.59it/s, L1=1.801, PSNR=34.5]
#
# ==================== Epoch 186 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9544  |  Pixel: 5.3011  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2678
#   ⚖️  [Discriminator] |  Real: 0.0189  |  Fake: 0.0150
#   📊 [Metrics Avg]   |  PSNR: 34.76 dB  |  Time: 58.1s  |  LR: 0.000028
# ------------------------------------------------------------
#
# Epoch 187: 100%|█████████| 150/150 [00:58<00:00,  2.58it/s, L1=8.839, PSNR=29.3]
#
# ==================== Epoch 187 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9549  |  Pixel: 5.4601  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2790
#   ⚖️  [Discriminator] |  Real: 0.0210  |  Fake: 0.0166
#   📊 [Metrics Avg]   |  PSNR: 35.73 dB  |  Time: 58.2s  |  LR: 0.000026
# ------------------------------------------------------------
#
# Epoch 188: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=8.189, PSNR=28.4]
#
# ==================== Epoch 188 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9755  |  Pixel: 5.3338  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2713
#   ⚖️  [Discriminator] |  Real: 0.0115  |  Fake: 0.0104
#   📊 [Metrics Avg]   |  PSNR: 34.75 dB  |  Time: 58.8s  |  LR: 0.000024
# ------------------------------------------------------------
#
# Epoch 189: 100%|█████████| 150/150 [00:59<00:00,  2.51it/s, L1=8.014, PSNR=34.2]
#
# ==================== Epoch 189 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9637  |  Pixel: 5.5633  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2827
#   ⚖️  [Discriminator] |  Real: 0.0152  |  Fake: 0.0147
#   📊 [Metrics Avg]   |  PSNR: 36.25 dB  |  Time: 59.8s  |  LR: 0.000022
# ------------------------------------------------------------
#
# Epoch 190: 100%|█████████| 150/150 [00:58<00:00,  2.56it/s, L1=5.012, PSNR=26.6]
#
# ==================== Epoch 190 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9640  |  Pixel: 5.4162  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2779
#   ⚖️  [Discriminator] |  Real: 0.0196  |  Fake: 0.0122
#   📊 [Metrics Avg]   |  PSNR: 34.51 dB  |  Time: 58.6s  |  LR: 0.000020
# ------------------------------------------------------------
#
# Epoch 191: 100%|█████████| 150/150 [00:59<00:00,  2.52it/s, L1=2.422, PSNR=43.0]
#
# ==================== Epoch 191 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9629  |  Pixel: 5.2082  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2672
#   ⚖️  [Discriminator] |  Real: 0.0140  |  Fake: 0.0139
#   📊 [Metrics Avg]   |  PSNR: 34.71 dB  |  Time: 59.6s  |  LR: 0.000018
# ------------------------------------------------------------
#
# Epoch 192: 100%|█████████| 150/150 [00:59<00:00,  2.54it/s, L1=6.166, PSNR=28.9]
#
# ==================== Epoch 192 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9689  |  Pixel: 5.3852  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2762
#   ⚖️  [Discriminator] |  Real: 0.0159  |  Fake: 0.0138
#   📊 [Metrics Avg]   |  PSNR: 36.64 dB  |  Time: 59.1s  |  LR: 0.000016
# ------------------------------------------------------------
#
# Epoch 193: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=2.590, PSNR=29.0]
#
# ==================== Epoch 193 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9630  |  Pixel: 5.2496  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2689
#   ⚖️  [Discriminator] |  Real: 0.0193  |  Fake: 0.0109
#   📊 [Metrics Avg]   |  PSNR: 34.22 dB  |  Time: 58.4s  |  LR: 0.000014
# ------------------------------------------------------------
#
# Epoch 194: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=3.777, PSNR=32.9]
#
# ==================== Epoch 194 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9622  |  Pixel: 5.3198  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2733
#   ⚖️  [Discriminator] |  Real: 0.0154  |  Fake: 0.0130
#   📊 [Metrics Avg]   |  PSNR: 35.09 dB  |  Time: 58.0s  |  LR: 0.000012
# ------------------------------------------------------------
#
# Epoch 195: 100%|█████████| 150/150 [00:58<00:00,  2.57it/s, L1=6.409, PSNR=27.5]
#
# ==================== Epoch 195 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9645  |  Pixel: 5.4473  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2780
#   ⚖️  [Discriminator] |  Real: 0.0140  |  Fake: 0.0121
#   📊 [Metrics Avg]   |  PSNR: 35.24 dB  |  Time: 58.5s  |  LR: 0.000010
# ------------------------------------------------------------
#
# Epoch 196: 100%|█████████| 150/150 [01:02<00:00,  2.39it/s, L1=4.963, PSNR=31.3]
#
# ==================== Epoch 196 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9731  |  Pixel: 5.2998  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0025  |  BG: 0.2694
#   ⚖️  [Discriminator] |  Real: 0.0136  |  Fake: 0.0092
#   📊 [Metrics Avg]   |  PSNR: 35.73 dB  |  Time: 63.0s  |  LR: 0.000008
# ------------------------------------------------------------
#
# Epoch 197: 100%|█████████| 150/150 [01:01<00:00,  2.44it/s, L1=9.546, PSNR=28.5]
#
# ==================== Epoch 197 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9689  |  Pixel: 5.3496  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2738
#   ⚖️  [Discriminator] |  Real: 0.0134  |  Fake: 0.0099
#   📊 [Metrics Avg]   |  PSNR: 34.87 dB  |  Time: 61.5s  |  LR: 0.000006
# ------------------------------------------------------------
#
# Epoch 198: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=1.067, PSNR=42.1]
#
# ==================== Epoch 198 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9725  |  Pixel: 5.5030  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2826
#   ⚖️  [Discriminator] |  Real: 0.0163  |  Fake: 0.0097
#   📊 [Metrics Avg]   |  PSNR: 35.07 dB  |  Time: 58.0s  |  LR: 0.000004
# ------------------------------------------------------------
#
# Epoch 199: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=6.121, PSNR=30.8]
#
# ==================== Epoch 199 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9552  |  Pixel: 5.3373  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2731
#   ⚖️  [Discriminator] |  Real: 0.0169  |  Fake: 0.0117
#   📊 [Metrics Avg]   |  PSNR: 36.12 dB  |  Time: 58.0s  |  LR: 0.000002
# ------------------------------------------------------------
#
# Epoch 200: 100%|█████████| 150/150 [00:57<00:00,  2.59it/s, L1=6.350, PSNR=26.2]
#
# ==================== Epoch 200 Summary ====================
#   🎨 [Generator Avg] |  GAN: 0.9579  |  Pixel: 5.3324  |  Edge: 0.0000  |  Perceptual: 0.0000  |  TV: 0.0000  |  SSIM: 0.0000  |  FFL: 0.0026  |  BG: 0.2720
#   ⚖️  [Discriminator] |  Real: 0.0156  |  Fake: 0.0147
#   📊 [Metrics Avg]   |  PSNR: 36.04 dB  |  Time: 58.1s  |  LR: 0.000000
# ------------------------------------------------------------
#
# 🏁 所有训练完成!

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 37_Base_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 38_Mild_Sharp1.5_FFL0.1_BG05 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 39_Hard_Sharp1.5_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results

  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 40_FFL_Mid_Sharp1.5_FFL0.5_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 41_FFL_Max_Sharp1.5_FFL1.0_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 42_Sharp2.0_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 43_Soft1.2_FFL0.1_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
  
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 44_Nuclear_Sharp1.5_FFL1.0_BG50 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results 
  
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 45_L1_Max_500_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results 


# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel/ \
  --name 46_NoDil_Sharp1.5_FFL0.1_BG20 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 37_Base_Sharp1.5_FFL0.1_BG20  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 37_Base_Sharp1.5_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/37_Base_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.42 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/37_Base_Sharp1.5_FFL0.1_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 38_Mild_Sharp1.5_FFL0.1_BG05  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 38_Mild_Sharp1.5_FFL0.1_BG05
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/38_Mild_Sharp1.5_FFL0.1_BG05/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.81 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/38_Mild_Sharp1.5_FFL0.1_BG05
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 39_Hard_Sharp1.5_FFL0.1_BG50  	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 39_Hard_Sharp1.5_FFL0.1_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/39_Hard_Sharp1.5_FFL0.1_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 49.66 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/39_Hard_Sharp1.5_FFL0.1_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 40_FFL_Mid_Sharp1.5_FFL0.5_BG20	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 40_FFL_Mid_Sharp1.5_FFL0.5_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/40_FFL_Mid_Sharp1.5_FFL0.5_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.50 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/40_FFL_Mid_Sharp1.5_FFL0.5_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 41_FFL_Max_Sharp1.5_FFL1.0_BG20	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 41_FFL_Max_Sharp1.5_FFL1.0_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/41_FFL_Max_Sharp1.5_FFL1.0_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 45.55 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/41_FFL_Max_Sharp1.5_FFL1.0_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 42_Sharp2.0_FFL0.1_BG20       	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 42_Sharp2.0_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/42_Sharp2.0_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.64 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/42_Sharp2.0_FFL0.1_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 43_Soft1.2_FFL0.1_BG50        	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 43_Soft1.2_FFL0.1_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/43_Soft1.2_FFL0.1_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.40 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/43_Soft1.2_FFL0.1_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 44_Nuclear_Sharp1.5_FFL1.0_BG50	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 44_Nuclear_Sharp1.5_FFL1.0_BG50
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/44_Nuclear_Sharp1.5_FFL1.0_BG50/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 46.82 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/44_Nuclear_Sharp1.5_FFL1.0_BG50
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 45_L1_Max_500_BG20            	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 45_L1_Max_500_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/45_L1_Max_500_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.85 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/45_L1_Max_500_BG20
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                 lambda_bg: 0.0
#                lambda_ffl: 0.0
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: 46_NoDil_Sharp1.5_FFL0.1_BG20 	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d                   	[default: resnet_9blocks]
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch                         	[default: instance]
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: 500                           	[default: inf]
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/results     	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#             use_attention: True                          	[default: False]
#              use_dilation: True                          	[default: False]
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): 46_NoDil_Sharp1.5_FFL0.1_BG20
# ================================================================================
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoints/46_NoDil_Sharp1.5_FFL0.1_BG20/latest_net_G.pth
# /home/liujia/3Channel/Clean_AUGAN/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.536 M
# -----------------------------------------------
# 📊 找到 1 个 LQ 测试文件
#
# Processing [1]: Simu_001
#   ✅ PSNR: 50.58 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/results/46_NoDil_Sharp1.5_FFL0.1_BG20
