# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_1channel/ \
  --name 16_GAN5_Edge0_Percep0_TV0_L1_20_SSIM1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 20.0 \
  --lambda_gan 5.0 \
  --lambda_perceptual 0.0 \
  --lambda_tv 0.0 \
  --lambda_edge 0.0 \
  --lambda_ssim 1.0 \
  --gpu_ids 0 \
  --norm batch \
  --no_flip
# Out:
# ----------------- Options ---------------
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_1channel/	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#               lambda_edge: 0.0
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/simu_1channel \
  --name 16_GAN5_Edge0_Percep0_TV0_L1_20_SSIM1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq test_lq \
  --dir_sq test_sq \
  --model augan \
  --netG unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --no_flip \
  --epoch latest \
  --num_test 10 \
  --results_dir /mnt/g/train_data/results
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/simu_1channel	[default: None]
#              dataset_mode: unaligned
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
# ...
