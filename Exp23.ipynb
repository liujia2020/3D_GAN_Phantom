# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --continue_train \
  --epoch_count 66

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --results_dir /mnt/g/train_data/result_Phantom
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Phantom/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
#                 load_iter: 0                             	[default: 0]
#                     model: augan                         	[default: test]
#                n_layers_D: 3
#                      name: O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: res_unet_3d
#                       ngf: 64
#                no_dropout: False
#                no_elastic: False
#                   no_flip: True                          	[default: False]
#                      norm: batch
#                  norm_max: 0.0
#                  norm_min: -60.0
#                  num_test: inf
#               num_threads: 4
#                 output_nc: 1
#              patch_size_d: 64
#              patch_size_h: 128
#              patch_size_w: 128
#                     phase: test
#               results_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./results/]
#             save_vol_only: False
#            serial_batches: False
#                 spacing_x: 1.0
#                 spacing_z: 1.0
#                    suffix:
#                  use_aspp: False
#             use_attention: True                          	[default: False]
#              use_dilation: False
#                   verbose: False
# ----------------- End -------------------
#
# ================================================================================
# 🚀 全卷测试 (Resave Mode): O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone
# ================================================================================
# /home/liujia/miniconda3/envs/augan_wsl/lib/python3.10/site-packages/torch/nn/init.py:511: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# model [AuganModel] was created
# loading the model from /mnt/g/train_data/checkpoint_Phantom/O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone/latest_net_G.pth
# /home/liujia/3D_GAN_Phantom/models/base_model.py:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(load_path, map_location=str(self.device))
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 155.729 M
# -----------------------------------------------
# 📊 找到 3 个 LQ 测试文件
#
# Processing [1]: Carotid_005
#   ✅ PSNR: 29.29 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# Processing [2]: Phantom_010
#   ✅ PSNR: 31.59 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# Processing [3]: Phantom_100
#   ✅ PSNR: 32.16 dB
#   Saving shape: (1024, 128, 128) (Matches Orig: (1024, 128, 128))
#
# ✅ 完成! 所有对齐文件已保存至: /mnt/g/train_data/checkpoint_Phantom/O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone
