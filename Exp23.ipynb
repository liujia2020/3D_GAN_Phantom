# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --continue_train \
  --epoch_count 66

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name O_07_Phantom_L1w10_GANw1_SNTrue_FFLw0.1_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --results_dir /mnt/g/train_data/result_Phantom

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name 09_Phantom_L1w10_GANw1_SNTrue_DropTrue_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid_Muscle/ \
  --name 09_Phantom_L1w10_GANw1_SNTrue_DropTrue_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 10.0 \
  --lambda_gan 1.0 \
  --lambda_perceptual 0.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 0.0 \
  --depth_weight_mode none \
  --use_sn \
  --use_dropout \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --continue_train \
  --epoch_count 91
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoint_Phantom	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid_Muscle/	[default: None]
#              dataset_mode: ultrasound
#          depth_weight_max: 5.0
#         depth_weight_mode: none
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 91                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom/ \
  --name 09_Phantom_L1w10_GANw1_SNTrue_DropTrue_DepthNone \
  --checkpoints_dir /mnt/g/train_data/checkpoint_Phantom \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --attn_temp 2.0 \
  --gpu_ids 0
