# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 63_Texture_SSIM_VGG \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch_count 1 \
  --lambda_pixel 50.0 \
  --lambda_gan 1.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  --lambda_ffl 0.0 \
  --lambda_bg 0.0
