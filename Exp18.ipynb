# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 70_Texture_SSIM_VGG \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch_count 1 \
  --lambda_pixel 50.0 \
  --lambda_gan 1.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  # --lambda_ffl 0.0 
  # --lambda_bg 0.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                lambda_ffl: 0.0
#                lambda_gan: 1.0
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom_Carotid/ \
  --name 70_Texture_SSIM_VGG \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --norm batch \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --lr 0.0002 \
  --norm_min -60.0 \
  --norm_max 0.0 \
  --epoch_count 1 \
  --lambda_pixel 50.0 \
  --lambda_gan 1.0 \
  --lambda_ssim 0.5 \
  --lambda_perceptual 1.0 \
  --lambda_tv 0.1 \
  # --lambda_ffl 0.0 
  # --lambda_bg 0.0
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.0
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Phantom_Carotid/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: True                          	[default: None]
#                lambda_ffl: 0.0
#                lambda_gan: 1.0
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_data_1channel/ \
  --name 71_Sharp2.0_FFL0.1_BG20_Simu \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 2.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --continue_train \
  --epoch_count 51
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: False
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_data_1channel/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_data_1channel/ \
  --name 71_Sharp2.0_FFL0.1_BG20_Simu \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lambda_pixel 200.0 \
  --lambda_gan 10.0 \
  --lambda_perceptual 0.0 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --gpu_ids 0 \
  --n_epochs 100 \
  --n_epochs_decay 100 \
  --attn_temp 2.0 \
  --lambda_ffl 0.1 \
  --lambda_bg 20.0 \
  --continue_train \
  --epoch_count 50
# Out:
# ----------------- Options ---------------
#                 attn_temp: 2.0                           	[default: 1.0]
#                batch_size: 2                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/Simu_data_1channel/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: Recon_LQ_03
#                    dir_sq: Recon_SQ_75
#                 direction: AtoB
#               display_dir: ./checkpoints
#              display_freq: 400
#                     epoch: latest
#               epoch_count: 50                            	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
# ...

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Simu_Data/ \
  --name 71_Sharp2.0_FFL0.1_BG20_Simu \
  --checkpoints_dir /mnt/g/train_data/checkpoints \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --model augan \
  --netG res_unet_3d \
  --input_nc 1 \
  --output_nc 1 \
  --batch_size 1 \
  --norm batch \
  --no_flip \
  --use_attention \
  --use_dilation \
  --attn_temp 1.5 \
  --epoch latest \
  --num_test 500 \
  --results_dir /mnt/g/train_data/results
# Out:
# ----------------- Options ---------------
#                 attn_temp: 1.5                           	[default: 1.0]
#                batch_size: 1
#           checkpoints_dir: /mnt/g/train_data/checkpoints 	[default: ./checkpoints]
#                  cropSize: 256
#                  dataroot: /home/liujia/g_linux/test/Simu_Data/	[default: None]
#              dataset_mode: ultrasound
#                    dir_lq: test_lq                       	[default: Recon_LQ_03]
#                    dir_sq: test_sq                       	[default: Recon_SQ_75]
#                 direction: AtoB
#               display_dir: ./checkpoints
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1
#                   isTrain: False                         	[default: None]
#                  loadSize: 286
# ...
